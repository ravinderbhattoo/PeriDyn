# %%
using Pkg

Pkg.activate("..")
using Revise

using PeriDyn
using PDMesh

using Random
using Distributed, Folds
# Out:
#   Activating environment at `/mnt/D/git_repos/PeriDyn/Project.toml`
# ┌ Info: Precompiling PeriDyn [c3db0ce0-6d7e-41b5-be11-bcb6aafada44]
# └ @ Base loading.jl:1342
# WARNING: Method definition (::Type{PeriDyn.PeridynamicsMaterial})(Any, Any, Any, Any) in module PeriDyn at /mnt/D/git_repos/PeriDyn/src/materials/material.jl:17 overwritten at /mnt/D/git_repos/PeriDyn/src/materials/pairwiseNN.jl:26.
#   ** incremental compilation may be fatally broken for this module **

# %%
PeriDyn.TIMEIT_REF[] = true
Random.seed!(42)

resolution = 1
# Out:
# 1

# %%
x1, v1, y1, vol1, type1 = create(Cuboid([-5 5; -5 5; -5 5]), resolution=resolution, type=1)

v1[1,:] .= 0.01

hor1 = 3.0
mat_gen1 = GeneralMaterial(y1, v1, x1, vol1, type1, hor1, max_neigh=200)

K, G = 1.0, 1.0
den1 = 10000.0
cstretch1 = 0.5
mat_spec1 = OrdinaryStateBasedSpecific([K], [G], [cstretch1], [den1])
# mat_spec1 = SkipSpecific([den1])

block1 = PeridynamicsMaterial(mat_gen1, mat_spec1; name="block 1")
# Out:
# Average family members: 66.264
# OrdinaryStateBasedMaterial("block 1", 1:1, GeneralMaterial
# type: [1]
# horizon: 3.0
# particle size: [1.0]
# , OrdinaryStateBasedSpecific
# bulk_modulus: [1.0]
# shear_modulus: [1.0]
# critical_stretch: [0.5]
# density: [10000.0]
# )

# %%
x2, v2, y2, vol2, type2 = create(move(Cuboid([-5 5; -5 5; -5 5]), by=[0, 50.0, 0.0]), resolution=resolution, type=2)

v2[1,:] .= 0.01

hor2 = 3.0
mat_gen2 = GeneralMaterial(y2, v2, x2, vol2, type2, hor2, max_neigh=200)

K2, G2 = 1.0, 1.0
den2 = 10000.0
cstretch2 = 0.5
mat_spec2 = OrdinaryStateBasedSpecific([K2], [G2], [cstretch2], [den2])
# mat_spec2 = SkipSpecific([den2])

block2 = PeridynamicsMaterial(mat_gen2, mat_spec2; name="block 2")
# Out:
# Average family members: 66.264
# OrdinaryStateBasedMaterial("block 2", 2:2, GeneralMaterial
# type: [2]
# horizon: 3.0
# particle size: [1.0]
# , OrdinaryStateBasedSpecific
# bulk_modulus: [1.0]
# shear_modulus: [1.0]
# critical_stretch: [0.5]
# density: [10000.0]
# )

# %%
x2, v2, y2, vol2, type2 = create(move(Cuboid([-5 5; -5 5; -5 5]), by=[24.0, 25.0, 0.0]), resolution=resolution, type=3)

v2[1,:] .-= 0.01

hor2 = 3.0
mat_gen2 = GeneralMaterial(y2, v2, x2, vol2, type2, hor2, max_neigh=200)

K2, G2 = 1.0, 1.0
den2 = 10000.0
cstretch2 = 0.5
mat_spec2 = OrdinaryStateBasedSpecific([K2], [G2], [cstretch2], [den2])
# mat_spec2 = SkipSpecific([den2])

block3 = PeridynamicsMaterial(mat_gen2, mat_spec2; name="block 2")
# Out:
# Average family members: 66.264
# OrdinaryStateBasedMaterial("block 2", 3:3, GeneralMaterial
# type: [3]
# horizon: 3.0
# particle size: [1.0]
# , OrdinaryStateBasedSpecific
# bulk_modulus: [1.0]
# shear_modulus: [1.0]
# critical_stretch: [0.5]
# density: [10000.0]
# )

# %%
x2, v2, y2, vol2, type2 = create(move(Cuboid([-5 5; -5 55; -5 5]), by=[12, 0, 0.0]), resolution=resolution, type=4)

v2[3,:] .= 0.0

hor2 = 3.0
mat_gen2 = GeneralMaterial(y2, v2, x2, vol2, type2, hor2, max_neigh=200)

K2, G2 = 1.0, 1.0
den2 = 1000.0
cstretch2 = 0.5
mat_spec2 = OrdinaryStateBasedSpecific([K2], [G2], [cstretch2], [den2])
# mat_spec2 = SkipSpecific([den2])

block4 = PeridynamicsMaterial(mat_gen2, mat_spec2; name="block 2")
# Out:
# Average family members: 72.744
# OrdinaryStateBasedMaterial("block 2", 4:4, GeneralMaterial
# type: [4]
# horizon: 3.0
# particle size: [1.0]
# , OrdinaryStateBasedSpecific
# bulk_modulus: [1.0]
# shear_modulus: [1.0]
# critical_stretch: [0.5]
# density: [1000.0]
# )

# %%
k = 1000.0
blocks = [block1, block2, block3, block4]

RM = [
        [LinearRepulsionModel(k, b1, distanceX=2, max_neighs=200) for b1 in blocks]..., 
        [LinearRepulsionModel(k, blocks[i], blocks[j], distanceX=2, max_neighs=200) for i in 2:4 for j in 1:i-1]...
    ]

env = Env(1, blocks, RM, [], 0.5)

nothing
#

# %%
velocity_verlet!([env], 5000, filewrite_freq=10, neigh_update_freq=10, file_prefix="2blocks", start_at=5000)
# Out:
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.464
# Average repulsive neighs: 0.4643333333333333
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.637271214642263
# Done
# 50.01%
# 50.02%
# 50.03%
# 50.04%
# 50.05%
# 50.06%
# 50.07%
# 50.08%
# 50.09%
# Momentum: 5010[100000.00000000015; 6.846079259048565e-12; 2.566391543723512e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.49
# Average repulsive neighs: 0.4676666666666667
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.690756302521009
# 50.1%
# 50.11%
# 50.12%
# 50.13%
# 50.14%
# 50.15%
# 50.16%
# 50.17%
# 50.18%
# 50.19%
# Momentum: 5020[100000.00000000033; 4.686029342337861e-12; -7.338574192772285e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.5
# Average repulsive neighs: 0.4756666666666667
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.7244294167371095
# 50.2%
# 50.21%
# 50.22%
# 50.23%
# 50.24%
# 50.25%
# 50.26%
# 50.27%
# 50.28%
# 50.29%
# Momentum: 5030[99999.99999999946; -7.815970093361102e-13; 1.2314593789142236e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.514
# Average repulsive neighs: 0.4786666666666667
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.724108658743633
# 50.3%
# 50.31%
# 50.32%
# 50.33%
# 50.34%
# 50.35%
# 50.36%
# 50.37%
# 50.38%
# 50.39%
# Momentum: 5040[100000.00000000068; 7.687850356319359e-12; -2.9958258096485224e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.53
# Average repulsive neighs: 0.4776666666666667
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.7527612574341545
# 50.4%
# 50.41%
# 50.42%
# 50.43%
# 50.44%
# 50.45%
# 50.46%
# 50.47%
# 50.48%
# 50.49%
# Momentum: 5050[99999.99999999932; 9.086065233532281e-13; -9.454215188497983e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.538
# Average repulsive neighs: 0.483
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.761864406779661
# 50.5%
# 50.51%
# 50.52%
# 50.53%
# 50.54%
# 50.55%
# 50.56%
# 50.57%
# 50.58%
# 50.59%
# Momentum: 5060[99999.99999999953; 1.2075673794242903e-11; -6.501466032204917e-13]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.568
# Average repulsive neighs: 0.49033333333333334
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.7982978723404255
# 50.6%
# 50.61%
# 50.62%
# 50.63%
# 50.64%
# 50.65%
# 50.66%
# 50.67%
# 50.68%
# 50.69%
# Momentum: 5070[100000.00000000006; 1.1617373729677638e-12; -3.9257486150745535e-13]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.582
# Average repulsive neighs: 0.493
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.796610169491525
# 50.7%
# 50.71%
# 50.72%
# 50.73%
# 50.74%
# 50.75%
# 50.76%
# 50.77%
# 50.78%
# 50.79%
# Momentum: 5080[99999.99999999985; -4.5563552930616424e-12; -3.383959779057477e-13]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.598
# Average repulsive neighs: 0.49
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.8331914893617025
# 50.8%
# 50.81%
# 50.82%
# 50.83%
# 50.84%
# 50.85%
# 50.86%
# 50.87%
# 50.88%
# 50.89%
# Momentum: 5090[100000.00000000048; 6.406430941297003e-12; -3.2076563627470023e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.624
# Average repulsive neighs: 0.48133333333333334
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.844255319148936
# 50.9%
# 50.91%
# 50.92%
# 50.93%
# 50.94%
# 50.95%
# 50.96%
# 50.97%
# 50.98%
# 50.99%
# Momentum: 5100[100000.00000000106; 1.3337886350939243e-11; -4.957367849556249e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.65
# Average repulsive neighs: 0.48133333333333334
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.878761822871883
# 51.0%
# 51.01%
# 51.02%
# 51.03%
# 51.04%
# 51.05%
# 51.06%
# 51.07%
# 51.08%
# 51.09%
# Momentum: 5110[100000.0000000002; 9.911182985433697e-12; 1.0696332708448608e-11]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.674
# Average repulsive neighs: 0.483
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.877374784110535
# 51.1%
# 51.11%
# 51.12%
# 51.13%
# 51.14%
# 51.15%
# 51.16%
# 51.17%
# 51.18%
# 51.19%
# Momentum: 5120[99999.9999999995; 4.671818487622659e-13; 3.76099151822018e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.714
# Average repulsive neighs: 0.493
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.924149956408021
# 51.2%
# 51.21%
# 51.22%
# 51.23%
# 51.24%
# 51.25%
# 51.26%
# 51.27%
# 51.28%
# 51.29%
# Momentum: 5130[99999.99999999988; 6.52722320637622e-12; -2.4677482279855667e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.74
# Average repulsive neighs: 0.512
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.95679012345679
# 51.3%
# 51.31%
# 51.32%
# 51.33%
# 51.34%
# 51.35%
# 51.36%
# 51.37%
# 51.38%
# 51.39%
# Momentum: 5140[99999.99999999984; 3.1874503036988244e-12; 1.1276049538544441e-11]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.764
# Average repulsive neighs: 0.524
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.997335701598579
# 51.4%
# 51.41%
# 51.42%
# 51.43%
# 51.44%
# 51.45%
# 51.46%
# 51.47%
# 51.48%
# 51.49%
# Momentum: 5150[99999.9999999997; 1.7763568394002505e-12; -3.03235214715869e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.792
# Average repulsive neighs: 0.5366666666666666
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 5.005342831700801
# 51.5%
# 51.51%
# 51.52%
# 51.53%
# 51.54%
# 51.55%
# 51.56%
# 51.57%
# 51.58%
# 51.59%
# Momentum: 5160[100000.00000000057; 5.835332217429823e-13; 2.950750754848741e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.836
# Average repulsive neighs: 0.5386666666666666
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 5.000889679715303
# 51.6%
# 51.61%
# 51.62%
# 51.63%
# 51.64%
# 51.65%
# 51.66%
# 51.67%
# 51.68%
# 51.69%
# Momentum: 5170[99999.99999999999; -5.559996907322784e-13; 3.157474282033945e-13]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.862
# Average repulsive neighs: 0.543
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.946724890829694
# 51.7%
# 51.71%
# 51.72%
# 51.73%
# 51.74%
# 51.75%
# 51.76%
# 51.77%
# 51.78%
# 51.79%
# Momentum: 5180[100000.00000000054; -7.220890552162018e-12; 2.062572335148616e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.908
# Average repulsive neighs: 0.5553333333333333
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.903812824956672
# 51.8%
# 51.81%
# 51.82%
# 51.83%
# 51.84%
# 51.85%
# 51.86%
# 51.87%
# 51.88%
# 51.89%
# Momentum: 5190[99999.99999999983; 3.764988321108831e-12; -1.7577050925865478e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.934
# Average repulsive neighs: 0.5626666666666666
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.870163370593294
# 51.9%
# 51.91%
# 51.92%
# 51.93%
# 51.94%
# 51.95%
# 51.96%
# 51.97%
# 51.98%
# 51.99%
# Momentum: 5200[99999.99999999988; 1.050093345611458e-11; -1.759037360216098e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.958
# Average repulsive neighs: 0.5633333333333334
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.857876712328767
# 52.0%
# 52.01%
# 52.02%
# 52.03%
# 52.04%
# 52.05%
# 52.06%
# 52.07%
# 52.08%
# 52.09%
# Momentum: 5210[100000.00000000038; 7.050804384789444e-12; 2.675193400136777e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.966
# Average repulsive neighs: 0.572
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.856655290102389
# 52.1%
# 52.11%
# 52.12%
# 52.13%
# 52.14%
# 52.15%
# 52.16%
# 52.17%
# 52.18%
# 52.19%
# Momentum: 5220[100000.0000000004; 1.0389022975232365e-11; -2.042810365310288e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.994
# Average repulsive neighs: 0.5783333333333334
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.827527612574341
# 52.2%
# 52.21%
# 52.22%
# 52.23%
# 52.24%
# 52.25%
# 52.26%
# 52.27%
# 52.28%
# 52.29%
# Momentum: 5230[99999.99999999999; 2.2168933355715126e-12; 1.8918200339612667e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.016
# Average repulsive neighs: 0.585
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.795262267343485
# 52.3%
# 52.31%
# 52.32%
# 52.33%
# 52.34%
# 52.35%
# 52.36%
# 52.37%
# 52.38%
# 52.39%
# Momentum: 5240[100000.00000000032; 8.15170153600775e-12; -9.740652728851273e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.03
# Average repulsive neighs: 0.5956666666666667
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.795435333896872
# 52.4%
# 52.41%
# 52.42%
# 52.43%
# 52.44%
# 52.45%
# 52.46%
# 52.47%
# 52.48%
# 52.49%
# Momentum: 5250[100000.00000000052; 4.064304448547773e-12; 1.7841284005726266e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.052
# Average repulsive neighs: 0.5946666666666667
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.7863175675675675
# 52.5%
# 52.51%
# 52.52%
# 52.53%
# 52.54%
# 52.55%
# 52.56%
# 52.57%
# 52.58%
# 52.59%
# Momentum: 5260[100000.00000000009; 1.389821591146756e-11; 4.495959160522034e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.084
# Average repulsive neighs: 0.5893333333333334
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.757118927973199
# 52.6%
# 52.61%
# 52.62%
# 52.63%
# 52.64%
# 52.65%
# 52.66%
# 52.67%
# 52.68%
# 52.69%
# Momentum: 5270[100000.00000000016; 1.3038459201197838e-12; -6.6773253593055415e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.104
# Average repulsive neighs: 0.5826666666666667
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.7280334728033475
# 52.7%
# 52.71%
# 52.72%
# 52.73%
# 52.74%
# 52.75%
# 52.76%
# 52.77%
# 52.78%
# 52.79%
# Momentum: 5280[99999.9999999997; 5.1105786269545206e-12; -2.1014301410104963e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.108
# Average repulsive neighs: 0.5836666666666667
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.6786011656952535
# 52.8%
# 52.81%
# 52.82%
# 52.83%
# 52.84%
# 52.85%
# 52.86%
# 52.87%
# 52.88%
# 52.89%
# Momentum: 5290[99999.9999999995; 8.916423155369557e-12; -4.458655666894629e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.118
# Average repulsive neighs: 0.5806666666666667
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.6975
# 52.9%
# 52.91%
# 52.92%
# 52.93%
# 52.94%
# 52.95%
# 52.96%
# 52.97%
# 52.98%
# 52.99%
# Momentum: 5300[99999.99999999937; 8.039791055125534e-12; -2.53452814291677e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.126
# Average repulsive neighs: 0.5776666666666667
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.713928273561301
# 53.0%
# 53.01%
# 53.02%
# 53.03%
# 53.04%
# 53.05%
# 53.06%
# 53.07%
# 53.08%
# 53.09%
# Momentum: 5310[100000.00000000012; 2.326228099036598e-11; 5.360156762890256e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.132
# Average repulsive neighs: 0.5763333333333334
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.691986644407345
# 53.1%
# 53.11%
# 53.12%
# 53.13%
# 53.14%
# 53.15%
# 53.16%
# 53.17%
# 53.18%
# 53.19%
# Momentum: 5320[100000.0000000001; -9.99467175688551e-12; -9.109157872444484e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.144
# Average repulsive neighs: 0.5713333333333334
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.680300500834725
# 53.2%
# 53.21%
# 53.22%
# 53.23%
# 53.24%
# 53.25%
# 53.26%
# 53.27%
# 53.28%
# 53.29%
# Momentum: 5330[99999.99999999994; 1.4590106900413957e-11; 1.7532642004880472e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.16
# Average repulsive neighs: 0.5653333333333334
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.656354515050167
# 53.3%
# 53.31%
# 53.32%
# 53.33%
# 53.34%
# 53.35%
# 53.36%
# 53.37%
# 53.38%
# 53.39%
# Momentum: 5340[99999.99999999975; 5.915268275202834e-12; 5.572431405198586e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.164
# Average repulsive neighs: 0.561
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.651046025104603
# 53.4%
# 53.41%
# 53.42%
# 53.43%
# 53.44%
# 53.45%
# 53.46%
# 53.47%
# 53.48%
# 53.49%
# Momentum: 5350[100000.00000000079; 4.7477577425070194e-12; -4.937827924322846e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.168
# Average repulsive neighs: 0.5543333333333333
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.602682313495389
# 53.5%
# 53.51%
# 53.52%
# 53.53%
# 53.54%
# 53.55%
# 53.56%
# 53.57%
# 53.58%
# 53.59%
# Momentum: 5360[100000.00000000067; 1.403721583415063e-11; -4.375388940047742e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.176
# Average repulsive neighs: 0.5506666666666666
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.577051926298157
# 53.6%
# 53.61%
# 53.62%
# 53.63%
# 53.64%
# 53.65%
# 53.66%
# 53.67%
# 53.68%
# 53.69%
# Momentum: 5370[100000.0000000003; -1.1883827255587676e-12; 5.672129432809925e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.188
# Average repulsive neighs: 0.5466666666666666
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.555369127516778
# 53.7%
# 53.71%
# 53.72%
# 53.73%
# 53.74%
# 53.75%
# 53.76%
# 53.77%
# 53.78%
# 53.79%
# Momentum: 5380[100000.00000000055; -4.5421444383464404e-12; 5.844214001626824e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.196
# Average repulsive neighs: 0.541
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.568181818181818
# 53.8%
# 53.81%
# 53.82%
# 53.83%
# 53.84%
# 53.85%
# 53.86%
# 53.87%
# 53.88%
# 53.89%
# Momentum: 5390[100000.0000000007; -6.298683796757132e-12; -3.1392666244300926e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.182
# Average repulsive neighs: 0.545
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.550968828980624
# 53.9%
# 53.91%
# 53.92%
# 53.93%
# 53.94%
# 53.95%
# 53.96%
# 53.97%
# 53.98%
# 53.99%
# Momentum: 5400[100000.00000000017; -4.094502514817577e-12; 7.123190925995004e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.188
# Average repulsive neighs: 0.5373333333333333
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.517270429654592
# 54.0%
# 54.01%
# 54.02%
# 54.03%
# 54.04%
# 54.05%
# 54.06%
# 54.07%
# 54.08%
# 54.09%
# Momentum: 5410[100000.00000000006; 1.1450396186774014e-11; 6.033396005022951e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.198
# Average repulsive neighs: 0.5353333333333333
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.511784511784512
# 54.1%
# 54.11%
# 54.12%
# 54.13%
# 54.14%
# 54.15%
# 54.16%
# 54.17%
# 54.18%
# 54.19%
# Momentum: 5420[100000.00000000023; -3.424815986363683e-12; 3.375077994860476e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.2
# Average repulsive neighs: 0.5286666666666666
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.522325189553496
# 54.2%
# 54.21%
# 54.22%
# 54.23%
# 54.24%
# 54.25%
# 54.26%
# 54.27%
# 54.28%
# 54.29%
# Momentum: 5430[99999.99999999932; 8.44124770082999e-12; -1.0374312520156082e-11]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.214
# Average repulsive neighs: 0.5306666666666666
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.50126582278481
# 54.3%
# 54.31%
# 54.32%
# 54.33%
# 54.34%
# 54.35%
# 54.36%
# 54.37%
# 54.38%
# 54.39%
# Momentum: 5440[99999.99999999958; 1.9673151996357774e-13; 5.5233040363589225e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.23
# Average repulsive neighs: 0.5256666666666666
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.470935130581298
# 54.4%
# 54.41%
# 54.42%
# 54.43%
# 54.44%
# 54.45%
# 54.46%
# 54.47%
# 54.48%
# 54.49%
# Momentum: 5450[99999.99999999939; -1.9124701822192947e-12; -1.8411938640383596e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.234
# Average repulsive neighs: 0.516
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.439126784214945
# 54.5%
# 54.51%
# 54.52%
# 54.53%
# 54.54%
# 54.55%
# 54.56%
# 54.57%
# 54.58%
# 54.59%
# Momentum: 5460[100000.00000000012; 1.1468159755168017e-11; 9.441336601412331e-13]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.246
# Average repulsive neighs: 0.5073333333333333
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.43419949706622
# 54.6%
# 54.61%
# 54.62%
# 54.63%
# 54.64%
# 54.65%
# 54.66%
# 54.67%
# 54.68%
# 54.69%
# Momentum: 5470[100000.00000000051; 4.867217739956686e-13; -2.6645352591003757e-15]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.248
# Average repulsive neighs: 0.5036666666666667
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.3953098827470685
# 54.7%
# 54.71%
# 54.72%
# 54.73%
# 54.74%
# 54.75%
# 54.76%
# 54.77%
# 54.78%
# 54.79%
# Momentum: 5480[100000.00000000102; 4.2520154064362714e-13; -2.495559314752427e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.24
# Average repulsive neighs: 0.5083333333333333
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.401680672268908
# 54.8%
# 54.81%
# 54.82%
# 54.83%
# 54.84%
# 54.85%
# 54.86%
# 54.87%
# 54.88%
# 54.89%
# Momentum: 5490[99999.99999999943; 7.582379168979969e-12; -1.0105694059348025e-11]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.228
# Average repulsive neighs: 0.5023333333333333
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.371116708648195
# 54.9%
# 54.91%
# 54.92%
# 54.93%
# 54.94%
# 54.95%
# 54.96%
# 54.97%
# 54.98%
# 54.99%
# Momentum: 5500[99999.99999999985; 7.490896791750856e-12; -7.229772336359019e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.234
# Average repulsive neighs: 0.5073333333333333
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.342281879194631
# 55.0%
# 55.01%
# 55.02%
# 55.03%
# 55.04%
# 55.05%
# 55.06%
# 55.07%
# 55.08%
# 55.09%
# Momentum: 5510[99999.99999999981; 1.8678392166293634e-12; 3.447020446856186e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.23
# Average repulsive neighs: 0.505
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.306532663316583
# 55.1%
# 55.11%
# 55.12%
# 55.13%
# 55.14%
# 55.15%
# 55.16%
# 55.17%
# 55.18%
# 55.19%
# Momentum: 5520[100000.00000000016; 6.245670647331281e-12; 1.5409895581797173e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.222
# Average repulsive neighs: 0.5033333333333333
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.284157585917854
# 55.2%
# 55.21%
# 55.22%
# 55.23%
# 55.24%
# 55.25%
# 55.26%
# 55.27%
# 55.28%
# 55.29%
# Momentum: 5530[99999.99999999929; 7.707612326157687e-12; 4.1739944833807385e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.22
# Average repulsive neighs: 0.505
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.232635983263599
# 55.3%
# 55.31%
# 55.32%
# 55.33%
# 55.34%
# 55.35%
# 55.36%
# 55.37%
# 55.38%
# 55.39%
# Momentum: 5540[99999.99999999997; -1.1431744439960312e-11; 2.079225680517993e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.214
# Average repulsive neighs: 0.505
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.2023313905079105
# 55.4%
# 55.41%
# 55.42%
# 55.43%
# 55.44%
# 55.45%
# 55.46%
# 55.47%
# 55.48%
# 55.49%
# Momentum: 5550[99999.99999999971; 1.481925693269659e-12; -6.600942015211331e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.2
# Average repulsive neighs: 0.507
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.192821368948247
# 55.5%
# 55.51%
# 55.52%
# 55.53%
# 55.54%
# 55.55%
# 55.56%
# 55.57%
# 55.58%
# 55.59%
# Momentum: 5560[99999.9999999999; -4.157563182616286e-12; 2.6601221225774907e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.184
# Average repulsive neighs: 0.5066666666666667
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.198160535117057
# 55.6%
# 55.61%
# 55.62%
# 55.63%
# 55.64%
# 55.65%
# 55.66%
# 55.67%
# 55.68%
# 55.69%
# Momentum: 5570[99999.99999999994; 5.9642291105888035e-12; 8.110179194886769e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.166
# Average repulsive neighs: 0.49733333333333335
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.186241610738255
# 55.7%
# 55.71%
# 55.72%
# 55.73%
# 55.74%
# 55.75%
# 55.76%
# 55.77%
# 55.78%
# 55.79%
# Momentum: 5580[99999.99999999983; -4.106714968088454e-12; -4.2676973066591017e-13]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.146
# Average repulsive neighs: 0.495
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.184873949579832
# 55.8%
# 55.81%
# 55.82%
# 55.83%
# 55.84%
# 55.85%
# 55.86%
# 55.87%
# 55.88%
# 55.89%
# Momentum: 5590[99999.99999999987; 1.2503331703328513e-11; 9.636735853746359e-14]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.134
# Average repulsive neighs: 0.49333333333333335
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.155778894472362
# 55.9%
# 55.91%
# 55.92%
# 55.93%
# 55.94%
# 55.95%
# 55.96%
# 55.97%
# 55.98%
# 55.99%
# Momentum: 5600[100000.00000000006; 1.5378809337107668e-12; 2.886579864025407e-13]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.11
# Average repulsive neighs: 0.4856666666666667
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.1267723102585485
# 56.0%
# 56.01%
# 56.02%
# 56.03%
# 56.04%
# 56.05%
# 56.06%
# 56.07%
# 56.08%
# 56.09%
# Momentum: 5610[99999.99999999983; -1.2563283746658271e-12; 2.922107000813412e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.088
# Average repulsive neighs: 0.483
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.083056478405315
# 56.1%
# 56.11%
# 56.12%
# 56.13%
# 56.14%
# 56.15%
# 56.16%
# 56.17%
# 56.18%
# 56.19%
# Momentum: 5620[99999.99999999999; 1.2989609388114332e-12; 1.056932319443149e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.082
# Average repulsive neighs: 0.47533333333333333
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.075581395348837
# 56.2%
# 56.21%
# 56.22%
# 56.23%
# 56.24%
# 56.25%
# 56.26%
# 56.27%
# 56.28%
# 56.29%
# Momentum: 5630[100000.00000000077; 1.3314682689724577e-11; 2.0765611452588928e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.068
# Average repulsive neighs: 0.4683333333333333
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.046319272125724
# 56.3%
# 56.31%
# 56.32%
# 56.33%
# 56.34%
# 56.35%
# 56.36%
# 56.37%
# 56.38%
# 56.39%
# Momentum: 5640[99999.99999999968; 1.2895462475626118e-11; -1.7639223415244487e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 1.022
# Average repulsive neighs: 0.46
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.031404958677686
# 56.4%
# 56.41%
# 56.42%
# 56.43%
# 56.44%
# 56.45%
# 56.46%
# 56.47%
# 56.48%
# 56.49%
# Momentum: 5650[99999.9999999999; 9.757528118825576e-12; -2.419398015263141e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.984
# Average repulsive neighs: 0.4533333333333333
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.0148270181219115
# 56.5%
# 56.51%
# 56.52%
# 56.53%
# 56.54%
# 56.55%
# 56.56%
# 56.57%
# 56.58%
# 56.59%
# Momentum: 5660[100000.00000000013; 1.3754997141290914e-11; 1.9317880628477724e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.938
# Average repulsive neighs: 0.44766666666666666
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.0395061728395065
# 56.6%
# 56.61%
# 56.62%
# 56.63%
# 56.64%
# 56.65%
# 56.66%
# 56.67%
# 56.68%
# 56.69%
# Momentum: 5670[99999.99999999919; 3.118646725412677e-12; 4.338751580235112e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.912
# Average repulsive neighs: 0.44366666666666665
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.0636363636363635
# 56.7%
# 56.71%
# 56.72%
# 56.73%
# 56.74%
# 56.75%
# 56.76%
# 56.77%
# 56.78%
# 56.79%
# Momentum: 5680[100000.00000000016; 8.308687071689747e-12; 2.7058355556164315e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.898
# Average repulsive neighs: 0.433
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.055371900826446
# 56.8%
# 56.81%
# 56.82%
# 56.83%
# 56.84%
# 56.85%
# 56.86%
# 56.87%
# 56.88%
# 56.89%
# Momentum: 5690[100000.00000000003; 9.276135415348108e-12; -7.611689056830073e-13]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.864
# Average repulsive neighs: 0.42633333333333334
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.04387417218543
# 56.9%
# 56.91%
# 56.92%
# 56.93%
# 56.94%
# 56.95%
# 56.96%
# 56.97%
# 56.98%
# 56.99%
# Momentum: 5700[99999.99999999933; -2.3441248941935555e-12; 1.270095140171179e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.824
# Average repulsive neighs: 0.41433333333333333
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.030629139072848
# 57.0%
# 57.01%
# 57.02%
# 57.03%
# 57.04%
# 57.05%
# 57.06%
# 57.07%
# 57.08%
# 57.09%
# Momentum: 5710[100000.0000000002; 6.753708703399752e-12; -1.6289192217300297e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.808
# Average repulsive neighs: 0.4106666666666667
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.029875518672199
# 57.1%
# 57.11%
# 57.12%
# 57.13%
# 57.14%
# 57.15%
# 57.16%
# 57.17%
# 57.18%
# 57.19%
# Momentum: 5720[99999.99999999936; 4.603650793910674e-12; 6.45705711121991e-13]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.776
# Average repulsive neighs: 0.401
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.022518765638032
# 57.2%
# 57.21%
# 57.22%
# 57.23%
# 57.24%
# 57.25%
# 57.26%
# 57.27%
# 57.28%
# 57.29%
# Momentum: 5730[100000.00000000017; 3.665290293497492e-12; -4.618527782440651e-13]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.754
# Average repulsive neighs: 0.394
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.0075
# 57.3%
# 57.31%
# 57.32%
# 57.33%
# 57.34%
# 57.35%
# 57.36%
# 57.37%
# 57.38%
# 57.39%
# Momentum: 5740[100000.00000000045; -2.6711965972481266e-12; 6.03073146976385e-13]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.726
# Average repulsive neighs: 0.3873333333333333
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.007550335570469
# 57.4%
# 57.41%
# 57.42%
# 57.43%
# 57.44%
# 57.45%
# 57.46%
# 57.47%
# 57.48%
# 57.49%
# Momentum: 5750[100000.00000000006; 8.61244409122719e-12; 5.3734794391857577e-14]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.706
# Average repulsive neighs: 0.382
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 4.004201680672269
# 57.5%
# 57.51%
# 57.52%
# 57.53%
# 57.54%
# 57.55%
# 57.56%
# 57.57%
# 57.58%
# 57.59%
# Momentum: 5760[99999.9999999996; -1.6675549829869851e-12; 7.212008767965017e-13]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.692
# Average repulsive neighs: 0.375
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 3.9849498327759196
# 57.6%
# 57.61%
# 57.62%
# 57.63%
# 57.64%
# 57.65%
# 57.66%
# 57.67%
# 57.68%
# 57.69%
# Momentum: 5770[99999.99999999946; 1.7415513475782518e-11; -1.2758682998992299e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.67
# Average repulsive neighs: 0.36666666666666664
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 3.9484193011647255
# 57.7%
# 57.71%
# 57.72%
# 57.73%
# 57.74%
# 57.75%
# 57.76%
# 57.77%
# 57.78%
# 57.79%
# Momentum: 5780[99999.99999999942; 1.783007075317755e-11; 7.140954494389007e-13]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.644
# Average repulsive neighs: 0.3566666666666667
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 3.9381270903010033
# 57.8%
# 57.81%
# 57.82%
# 57.83%
# 57.84%
# 57.85%
# 57.86%
# 57.87%
# 57.88%
# 57.89%
# Momentum: 5790[99999.99999999967; 1.6967496851982844e-11; 4.991562718714704e-13]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.618
# Average repulsive neighs: 0.348
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 3.959527824620573
# 57.9%
# 57.91%
# 57.92%
# 57.93%
# 57.94%
# 57.95%
# 57.96%
# 57.97%
# 57.98%
# 57.99%
# Momentum: 5800[100000.00000000022; 1.7224791037939724e-11; -2.773781204723491e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.584
# Average repulsive neighs: 0.3486666666666667
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 3.9535864978902953
# 58.0%
# 58.01%
# 58.02%
# 58.03%
# 58.04%
# 58.05%
# 58.06%
# 58.07%
# 58.08%
# 58.09%
# Momentum: 5810[100000.00000000029; 8.93285445613401e-13; 2.8750335445693054e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.558
# Average repulsive neighs: 0.3396666666666667
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 3.9451013513513513
# 58.1%
# 58.11%
# 58.12%
# 58.13%
# 58.14%
# 58.15%
# 58.16%
# 58.17%
# 58.18%
# 58.19%
# Momentum: 5820[100000.00000000087; 4.969358258222201e-12; 1.1759482276829658e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.548
# Average repulsive neighs: 0.3406666666666667
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 3.9168787107718406
# 58.2%
# 58.21%
# 58.22%
# 58.23%
# 58.24%
# 58.25%
# 58.26%
# 58.27%
# 58.28%
# 58.29%
# Momentum: 5830[99999.99999999983; 2.3163693185779266e-12; 3.006928039894774e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.502
# Average repulsive neighs: 0.337
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 3.901444350042481
# 58.3%
# 58.31%
# 58.32%
# 58.33%
# 58.34%
# 58.35%
# 58.36%
# 58.37%
# 58.38%
# 58.39%
# Momentum: 5840[100000.00000000074; -1.042899100411887e-11; 5.639932965095795e-14]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.48
# Average repulsive neighs: 0.334
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 3.8813559322033897
# 58.4%
# 58.41%
# 58.42%
# 58.43%
# 58.44%
# 58.45%
# 58.46%
# 58.47%
# 58.48%
# 58.49%
# Momentum: 5850[100000.00000000057; -8.384404281969182e-13; -1.3202494653086205e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.45
# Average repulsive neighs: 0.33666666666666667
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 3.8244725738396625
# 58.5%
# 58.51%
# 58.52%
# 58.53%
# 58.54%
# 58.55%
# 58.56%
# 58.57%
# 58.58%
# 58.59%
# Momentum: 5860[100000.0000000002; 5.123013124830322e-12; 5.806466418789569e-13]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.426
# Average repulsive neighs: 0.3293333333333333
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 3.8415254237288137
# 58.6%
# 58.61%
# 58.62%
# 58.63%
# 58.64%
# 58.65%
# 58.66%
# 58.67%
# 58.68%
# 58.69%
# Momentum: 5870[99999.99999999968; 5.9898752624576446e-12; 2.2466473126314668e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.4
# Average repulsive neighs: 0.328
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 3.836317135549872
# 58.7%
# 58.71%
# 58.72%
# 58.73%
# 58.74%
# 58.75%
# 58.76%
# 58.77%
# 58.78%
# 58.79%
# ...
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 0.9465875370919882
# 86.7%
# 86.71%
# 86.72%
# 86.73%
# 86.74%
# 86.75%
# 86.76%
# 86.77%
# 86.78%
# 86.79%
# Momentum: 8680[99999.99999999933; 1.503153157500492e-11; 2.099209694961246e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.156
# Average repulsive neighs: 0.13333333333333333
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 1.0
# 86.8%
# 86.81%
# 86.82%
# 86.83%
# 86.84%
# 86.85%
# 86.86%
# 86.87%
# 86.88%
# 86.89%
# Momentum: 8690[99999.99999999956; -5.60440582830779e-12; -6.421529974431905e-13]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.142
# Average repulsive neighs: 0.13333333333333333
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 1.0396341463414633
# 86.9%
# 86.91%
# 86.92%
# 86.93%
# 86.94%
# 86.95%
# 86.96%
# 86.97%
# 86.98%
# 86.99%
# Momentum: 8700[99999.99999999997; 9.753975405146775e-12; 3.6495251265478146e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.136
# Average repulsive neighs: 0.13333333333333333
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 1.1253822629969419
# 87.0%
# 87.01%
# 87.02%
# 87.03%
# 87.04%
# 87.05%
# 87.06%
# 87.07%
# 87.08%
# 87.09%
# Momentum: 8710[100000.00000000029; 1.0675904604795505e-11; -5.755396159656812e-13]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.122
# Average repulsive neighs: 0.13333333333333333
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 1.1993769470404985
# 87.1%
# 87.11%
# 87.12%
# 87.13%
# 87.14%
# 87.15%
# 87.16%
# 87.17%
# 87.18%
# 87.19%
# Momentum: 8720[99999.99999999964; 1.5292656030396756e-11; 2.4202861936828413e-13]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.12
# Average repulsive neighs: 0.13333333333333333
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 1.3344051446945338
# 87.2%
# 87.21%
# 87.22%
# 87.23%
# 87.24%
# 87.25%
# 87.26%
# 87.27%
# 87.28%
# 87.29%
# Momentum: 8730[100000.00000000054; 8.485656621814996e-12; 1.4455103780619538e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.112
# Average repulsive neighs: 0.13333333333333333
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 1.4262820512820513
# 87.3%
# 87.31%
# 87.32%
# 87.33%
# 87.34%
# 87.35%
# 87.36%
# 87.37%
# 87.38%
# 87.39%
# Momentum: 8740[100000.00000000025; 7.686296044084884e-12; -2.2634116803033066e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.11
# Average repulsive neighs: 0.13333333333333333
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 1.5311475409836066
# 87.4%
# 87.41%
# 87.42%
# 87.43%
# 87.44%
# 87.45%
# 87.46%
# 87.47%
# 87.48%
# 87.49%
# Momentum: 8750[99999.99999999958; 1.0697220886868308e-11; -4.2389980414725414e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.106
# Average repulsive neighs: 0.13333333333333333
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 1.6534653465346534
# 87.5%
# 87.51%
# 87.52%
# 87.53%
# 87.54%
# 87.55%
# 87.56%
# 87.57%
# 87.58%
# 87.59%
# Momentum: 8760[99999.99999999908; 1.4335199693960021e-12; 1.4011014570769476e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.108
# Average repulsive neighs: 0.13333333333333333
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 1.7633333333333334
# 87.6%
# 87.61%
# 87.62%
# 87.63%
# 87.64%
# 87.65%
# 87.66%
# 87.67%
# 87.68%
# 87.69%
# Momentum: 8770[99999.99999999991; 1.6141754599630076e-11; -5.204725539442734e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.108
# Average repulsive neighs: 0.13366666666666666
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 1.9427609427609427
# 87.7%
# 87.71%
# 87.72%
# 87.73%
# 87.74%
# 87.75%
# 87.76%
# 87.77%
# 87.78%
# 87.79%
# Momentum: 8780[99999.99999999984; 1.319833131674386e-12; -4.404476783292921e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.102
# Average repulsive neighs: 0.13366666666666666
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 2.0508474576271185
# 87.8%
# 87.81%
# 87.82%
# 87.83%
# 87.84%
# 87.85%
# 87.86%
# 87.87%
# 87.88%
# 87.89%
# Momentum: 8790[100000.00000000058; -3.945288540307956e-12; 8.677503160470224e-13]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.1
# Average repulsive neighs: 0.13366666666666666
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 2.2101694915254235
# 87.9%
# 87.91%
# 87.92%
# 87.93%
# 87.94%
# 87.95%
# 87.96%
# 87.97%
# 87.98%
# 87.99%
# Momentum: 8800[99999.99999999956; 1.5724310742371017e-11; -6.936673457857978e-13]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.102
# Average repulsive neighs: 0.13366666666666666
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 2.272727272727273
# 88.0%
# 88.01%
# 88.02%
# 88.03%
# 88.04%
# 88.05%
# 88.06%
# 88.07%
# 88.08%
# 88.09%
# Momentum: 8810[100000.0000000002; 1.1599610161283636e-12; -1.7195134205394424e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.096
# Average repulsive neighs: 0.13366666666666666
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 2.278688524590164
# 88.1%
# 88.11%
# 88.12%
# 88.13%
# 88.14%
# 88.15%
# 88.16%
# 88.17%
# 88.18%
# 88.19%
# Momentum: 8820[100000.00000000054; 7.531752999057062e-13; -2.5135449277513544e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.094
# Average repulsive neighs: 0.13366666666666666
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 2.3099041533546325
# 88.2%
# 88.21%
# 88.22%
# 88.23%
# 88.24%
# 88.25%
# 88.26%
# 88.27%
# 88.28%
# 88.29%
# Momentum: 8830[99999.99999999988; 1.786304437700892e-11; 2.851052727237402e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.094
# Average repulsive neighs: 0.134
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 2.3773584905660377
# 88.3%
# 88.31%
# 88.32%
# 88.33%
# 88.34%
# 88.35%
# 88.36%
# 88.37%
# 88.38%
# 88.39%
# Momentum: 8840[100000.00000000036; 3.078426402680634e-12; -2.332356530132529e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.092
# Average repulsive neighs: 0.13433333333333333
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 2.5348101265822787
# 88.4%
# 88.41%
# 88.42%
# 88.43%
# 88.44%
# 88.45%
# 88.46%
# 88.47%
# 88.48%
# 88.49%
# Momentum: 8850[100000.00000000035; 1.2458478693133657e-11; -3.637534717881863e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.09
# Average repulsive neighs: 0.13433333333333333
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 2.6561514195583595
# 88.5%
# 88.51%
# 88.52%
# 88.53%
# 88.54%
# 88.55%
# 88.56%
# 88.57%
# 88.58%
# 88.59%
# Momentum: 8860[100000.0000000003; 1.2156498030435614e-11; -3.5624836414172023e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.09
# Average repulsive neighs: 0.13433333333333333
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 2.7125
# 88.6%
# 88.61%
# 88.62%
# 88.63%
# 88.64%
# 88.65%
# 88.66%
# 88.67%
# 88.68%
# 88.69%
# Momentum: 8870[99999.99999999959; 1.4522605340516748e-11; -2.682298827494378e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.09
# Average repulsive neighs: 0.13466666666666666
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 2.8495297805642634
# 88.7%
# 88.71%
# 88.72%
# 88.73%
# 88.74%
# 88.75%
# 88.76%
# 88.77%
# 88.78%
# 88.79%
# Momentum: 8880[99999.99999999981; 5.0528470296740124e-12; 3.326228181776969e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.09
# Average repulsive neighs: 0.13466666666666666
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 2.9778481012658227
# 88.8%
# 88.81%
# 88.82%
# 88.83%
# 88.84%
# 88.85%
# 88.86%
# 88.87%
# 88.88%
# 88.89%
# Momentum: 8890[99999.99999999916; 7.866596263284009e-12; 2.7971513993918506e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.086
# Average repulsive neighs: 0.13466666666666666
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 3.0445859872611467
# 88.9%
# 88.91%
# 88.92%
# 88.93%
# 88.94%
# 88.95%
# 88.96%
# 88.97%
# 88.98%
# 88.99%
# Momentum: 8900[100000.00000000013; -9.992007221626409e-12; 5.667154245880823e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.086
# Average repulsive neighs: 0.13466666666666666
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 3.1346153846153846
# 89.0%
# 89.01%
# 89.02%
# 89.03%
# 89.04%
# 89.05%
# 89.06%
# 89.07%
# 89.08%
# 89.09%
# Momentum: 8910[100000.00000000042; 1.368860580441833e-11; 8.010814234182817e-13]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.086
# Average repulsive neighs: 0.13466666666666666
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 3.2083333333333335
# 89.1%
# 89.11%
# 89.12%
# 89.13%
# 89.14%
# 89.15%
# 89.16%
# 89.17%
# 89.18%
# 89.19%
# Momentum: 8920[99999.99999999984; 1.1181278125604877e-11; 8.052392086455029e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.082
# Average repulsive neighs: 0.13466666666666666
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 3.3516129032258064
# 89.2%
# 89.21%
# 89.22%
# 89.23%
# 89.24%
# 89.25%
# 89.26%
# 89.27%
# 89.28%
# 89.29%
# Momentum: 8930[100000.0000000003; 1.361577517400292e-11; -2.629896300732071e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.082
# Average repulsive neighs: 0.13466666666666666
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 3.565359477124183
# 89.3%
# 89.31%
# 89.32%
# 89.33%
# 89.34%
# 89.35%
# 89.36%
# 89.37%
# 89.38%
# 89.39%
# Momentum: 8940[100000.00000000055; 1.3447021274259896e-12; -4.205524817280093e-13]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.082
# Average repulsive neighs: 0.13466666666666666
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 3.6885245901639343
# 89.4%
# 89.41%
# 89.42%
# 89.43%
# 89.44%
# 89.45%
# 89.46%
# 89.47%
# 89.48%
# 89.49%
# Momentum: 8950[100000.00000000052; 1.0370371228418662e-11; -4.529265851260789e-12]
#
# Writting data file................................
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.082
# Average repulsive neighs: 0.13466666666666666
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# No repulsive neighs.
# Average repulsive neighs: 3.789473684210526
# 89.5%
# 89.51%
# 89.52%
# 89.53%
# 89.54%
# 89.55%
# 89.56%
# 89.57%
# 89.58%

# %%
using StaticArrays, Folds

function PeriDyn.force_density_T(y::Array{Float64,2}, mat::OrdinaryStateBasedMaterial)
    force = zeros(size(y))
    types = mat.general.type
    S = mat.general
    m = mat.general.weighted_volume
    intact = S.intact
    family = S.family
    PeriDyn.@timeit theta = dilatation(y, S, m) "dilation"
    N = size(S.x, 2)

    Threads.@threads for i in 1:N
        for k in 1:size(S.family,1)
            j = S.family[k,i]
            if !S.intact[k,i]
                S.intact[k,i] = false
            else
                X = PeriDyn.@_ij(j,i,S.x)
                Y = PeriDyn.@_ij(j,i,y)
                yij = PeriDyn.@_magnitude(Y)
                xij = PeriDyn.@_magnitude(X)
                
                extention = yij - xij
                wij = influence_function(X)
                wji = influence_function(-X)
                type1 = types[i] - mat.type.start + 1
                type2 = types[j] - mat.type.start + 1
                if (extention/xij) < mat.specific.critical_stretch[type1, type2]
                    K = mat.specific.bulk_modulus[type1, type2]
                    G = mat.specific.shear_modulus[type1, type2]
                    a_, b_ = wij/m[i], wji/m[j]
                    t =  (3*K-5*G) * (theta[i]*xij*a_ + theta[j]*xij*b_)  + 15*G*extention*(a_ + b_) 
                    t = t*S.volume[j] / yij
                    force[1,i] += t*Y[1]
                    force[2,i] += t*Y[2]
                    force[3,i] += t*Y[3]
                else
                    S.intact[k,i] = false
                end
            end
        end
    end

    return force
end

PeriDyn.@timeit force_density_T(1.1*block1.general.x, block1) ""
# Out:
#   0.112404 seconds (194.62 k allocations: 11.841 MiB, 96.29% compilation time)
# Time taken for dilation:
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
#   0.499722 seconds (734.83 k allocations: 43.661 MiB, 41.86% compilation time)
# Time taken for :
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
# 3×1000 Matrix{Float64}:
#  0.291969  0.0942176  -0.0391089  …   0.0391089  -0.0942176  -0.291969
#  0.291969  0.314038    0.296241      -0.296241   -0.314038   -0.291969
#  0.291969  0.314038    0.296241      -0.296241   -0.314038   -0.291969

# %%
function PeriDyn.dilatation_theta(y::Array{Float64,2},S::GeneralMaterial)
    intact = S.intact
    family = S.family
    N = size(family, 2)

    function with_if_cal_theta_ij(i, j)
        X = PeriDyn.@_ij(j, i, S.x)
        Y = PeriDyn.@_ij(j, i, y)
        _X = PeriDyn.@_magnitude(X)
        _Y = PeriDyn.@_magnitude(Y)
        extention = _Y - _X
        return influence_function(X) * _X * extention * S.volume[j] * horizon_correction(X, S.particle_size, S.horizon)
    end

    inner_map(i, js) = mapreduce((j)-> with_if_cal_theta_ij(i,j), +, js)
    return Folds.map((i)->inner_map(i, family[intact[:, i], i]), 1:N)
    
end


S = block1.general
PeriDyn.@timeit dilatation(S.x*1.1, S, S.weighted_volume) ""
nothing
# Out:
#   0.091817 seconds (184.72 k allocations: 10.831 MiB, 88.24% compilation time)
# Time taken for :
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################

# %%
function PeriDyn.dilatation_theta(y::Array{Float64,2},S::GeneralMaterial)
    intact = S.intact
    family = S.family
    N = size(family, 2)
    M = size(family, 1)
    theta = 0*S.volume
    Threads.@threads for i in 1:N
        for k in 1:M
            j = S.family[k,i]
            if (j>0) & (intact[k, i])
                X = PeriDyn.@_ij(j, i, S.x)
                Y = PeriDyn.@_ij(j, i, y)
                _X = PeriDyn.@_magnitude(X)
                _Y = PeriDyn.@_magnitude(Y)
                extention = _Y - _X
                theta[i] += influence_function(X)*_X*extention*S.volume[j] * horizon_correction(X, S.particle_size, S.horizon)
            end
        end
    end
    return theta
end


S = block1.general
PeriDyn.@timeit dilatation(S.x*1.1, S, S.weighted_volume) ""
nothing
# Out:
#   0.103823 seconds (60.03 k allocations: 7.990 MiB, 66.31% compilation time)
# Time taken for :
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################

# %%
function PeriDyn.weighted_volume(x, volume, particle_size, family, horizon)
    N = size(family, 2)
    mask = family .> 0

    function cal_m_ij(i, j)
        X = [x[1,j]-x[1,i], x[2,j]-x[2,i], x[3,j]-x[3,i]]
        return influence_function(X)*_magnitude(X)^2*horizon_correction(X, particle_size, horizon)*volume[j]
    end
        
    inner_map(i, js) = mapreduce((j)-> cal_m_ij(i,j), +, js)
    return Folds.map((i)->inner_map(i, family[mask[:, i], i]), 1:N)
end


S = block1.general
PeriDyn.@timeit weighted_volume(S.x, S.volume, S.particle_size, S.family, S.horizon) ""
nothing
# Out:
#   4.320906 seconds (93.34 M allocations: 10.244 GiB, 40.22% gc time, 10.20% compilation time)
# Time taken for :
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################

# %%
function PeriDyn.weighted_volume(x, volume, particle_size, family, horizon)
    m = 0*volume
    dr = zeros(3)
    for i in 1:size(x,2)
        for k in 1:size(family,1)
            j = family[k,i]
            if (j>0)
                dr[1] = x[1,j]-x[1,i]
                dr[2] = x[2,j]-x[2,i]
                dr[3] = x[3,j]-x[3,i]
                m[i] += influence_function(dr)*_magnitude(dr)^2*horizon_correction(dr, particle_size,horizon)*volume[j]
            end
        end
    end
    return m
end

S = block1.general
PeriDyn.@timeit weighted_volume(S.x, S.volume, S.particle_size, S.family, S.horizon) ""
nothing
# Out:
#   0.684199 seconds (41.46 k allocations: 10.047 MiB, 6.13% compilation time)
# Time taken for :
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################

# %%
# @code_typed weighted_volume(S.x, S.volume, S.particle_size, S.family, S.horizon)

# %%
velocity_verlet!([env], 5000, filewrite_freq=10, neigh_update_freq=10, file_prefix="2blocks", start_at=0)
# Out:
# Updating neighbors for collision..................
# Average repulsive neighs: 15.625
# Done
# Material force calculation passed. [Undeformed]
#   0.752817 seconds (975.06 k allocations: 175.212 MiB, 4.31% gc time, 86.93% compilation time)
# Time taken for Material force calculations (block 1):
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
# Material force calculation passed. [Undeformed]
#   0.000137 seconds (70 allocations: 127.156 KiB)
# Time taken for Material force calculations (block 2):
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
#   1.223970 seconds (1.80 M allocations: 167.084 MiB, 3.79% gc time, 92.36% compilation time)
# Time taken for Short range repulsion calculations:
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
# Material force calculation passed. [Undeformed]
#   0.080547 seconds (187 allocations: 122.083 MiB, 7.18% gc time)
# Time taken for Material force calculations (block 1):
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
# Material force calculation passed. [Undeformed]
#   0.000138 seconds (70 allocations: 127.156 KiB)
# Time taken for Material force calculations (block 2):
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
#   0.069427 seconds (245.02 k allocations: 87.513 MiB, 8.24% gc time)
# Time taken for Short range repulsion calculations:
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
#   0.208920 seconds (245.93 k allocations: 317.396 MiB, 8.14% gc time)
# Time taken for update acceleration step:
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
#   0.231917 seconds (246.20 k allocations: 317.414 MiB, 7.34% gc time)
# Time taken for velocity verlet step:
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
# Momentum: 1[0.0; 0.0; -10000.0]
#
# Writting data file................................
# Material force calculation passed. [Undeformed]
#   0.094176 seconds (72 allocations: 122.073 MiB, 19.76% gc time)
# Time taken for Material force calculations (block 1):
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
# Material force calculation passed. [Undeformed]
#   0.000137 seconds (71 allocations: 127.688 KiB)
# Time taken for Material force calculations (block 2):
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
#   0.079262 seconds (245.02 k allocations: 87.513 MiB, 3.26% gc time)
# Time taken for Short range repulsion calculations:
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
#  12.843147 seconds (140.39 M allocations: 10.386 GiB, 10.44% gc time)
# Time taken for saving file to disk:
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
# Done
# 0.02%
#   1.867257 seconds (3.00 M allocations: 903.163 MiB, 13.97% gc time)
# Time taken for dilation:
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
#  14.513936 seconds (92.21 M allocations: 10.306 GiB, 12.66% gc time)
# Time taken for Material force calculations (block 1):
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
# Material force calculation passed. [Undeformed]
#   0.000136 seconds (70 allocations: 127.156 KiB)
# Time taken for Material force calculations (block 2):
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
#   0.070320 seconds (245.02 k allocations: 87.513 MiB, 14.54% gc time)
# Time taken for Short range repulsion calculations:
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
#  14.643912 seconds (92.45 M allocations: 10.497 GiB, 12.66% gc time)
# Time taken for update acceleration step:
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
#  14.666341 seconds (92.45 M allocations: 10.497 GiB, 12.64% gc time)
# Time taken for velocity verlet step:
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
# 0.04%
#   1.875054 seconds (3.00 M allocations: 903.163 MiB, 13.82% gc time)
# Time taken for dilation:
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
# InterruptException:
#
# Stacktrace:
#   [1] Array
#     @ ./boot.jl:448 [inlined]
#   [2] Array
#     @ ./boot.jl:457 [inlined]
#   [3] Array
#     @ ./boot.jl:465 [inlined]
#   [4] similar
#     @ ./abstractarray.jl:785 [inlined]
#   [5] similar
#     @ ./abstractarray.jl:784 [inlined]
#   [6] similar
#     @ ./broadcast.jl:197 [inlined]
#   [7] similar
#     @ ./broadcast.jl:196 [inlined]
#   [8] copy
#     @ ./broadcast.jl:908 [inlined]
#   [9] materialize
#     @ ./broadcast.jl:883 [inlined]
#  [10] broadcast_preserving_zero_d
#     @ ./broadcast.jl:872 [inlined]
#  [11] -(A::Vector{Float64})
#     @ Base ./arraymath.jl:30
#  [12] force_density_T(y::Matrix{Float64}, mat::OrdinaryStateBasedMaterial)
#     @ PeriDyn /mnt/D/git_repos/PeriDyn/src/materials/ordinary_state_based.jl:64
#  [13] force_density(y::Matrix{Float64}, mat::OrdinaryStateBasedMaterial)
#     @ PeriDyn /mnt/D/git_repos/PeriDyn/src/materials/material.jl:89
#  [14] macro expansion
#     @ ./timing.jl:210 [inlined]
#  [15] macro expansion
#     @ /mnt/D/git_repos/PeriDyn/src/PeriDyn.jl:30 [inlined]
#  [16] update_acc!(env::PeriDyn.GeneralEnv)
#     @ PeriDyn /mnt/D/git_repos/PeriDyn/src/solvers.jl:51
#  [17] macro expansion
#     @ ./timing.jl:210 [inlined]
#  [18] macro expansion
#     @ /mnt/D/git_repos/PeriDyn/src/PeriDyn.jl:30 [inlined]
#  [19] velocity_verlet_step!(env::PeriDyn.GeneralEnv)
#     @ PeriDyn /mnt/D/git_repos/PeriDyn/src/solvers.jl:95
#  [20] macro expansion
#     @ ./timing.jl:210 [inlined]
#  [21] macro expansion
#     @ /mnt/D/git_repos/PeriDyn/src/PeriDyn.jl:30 [inlined]
#  [22] velocity_verlet!(envs::Vector{PeriDyn.GeneralEnv}, N::Int64; filewrite_freq::Int64, average_prop_freq::Int64, neigh_update_freq::Int64, file_prefix::String, start_at::Int64)
#     @ PeriDyn /mnt/D/git_repos/PeriDyn/src/solvers.jl:144
#  [23] top-level scope
#     @ In[164]:1
#  [24] eval
#     @ ./boot.jl:360 [inlined]
#  [25] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1116

# %% [markdown]
# ## END

# %%
function PeriDyn.td_norm_fn(y, theta, mat)
    S = mat.general
    types = mat.general.type
    intact = S.intact
    family = S.family
    x = S.x
    N = size(family, 2)
    M = size(family, 1)
    ARGS = map((i) -> (i, 1:M), 1:N)    
    m = mat.general.weighted_volume
    function with_if_cal_td_norm(i, k)
        if intact[k,i]
            j = family[k, i]
            type1 = types[i] - mat.type.start + 1
            type2 = types[j] - mat.type.start + 1
            G = mat.specific.shear_modulus[type1, type2]
            edp = mat.specific.edp[k, i]

            X = [x[1,j]-x[1,i],x[2,j]-x[2,i],x[3,j]-x[3,i]]
            Y = [y[1,j]-y[1,i],y[2,j]-y[2,i],y[3,j]-y[3,i]]

            _X = _magnitude(X)
            _Y = _magnitude(Y)

            e = _Y - _X

            ed = e - theta[i] * _X / 3
                        
            ee = ed - edp

            s = e/_X

            wij = influence_function(X)::Float64
            wji = influence_function(-X)::Float64
            type1 = types[i] - mat.type.start + 1
            type2 = types[j] - mat.type.start + 1
            if s < mat.specific.critical_stretch[type1, type2]
                K = mat.specific.bulk_modulus[type1, type2]
                G = mat.specific.shear_modulus[type1, type2]
                td = 15*G*(ee*wij/m[i]+ee*wji/m[j])
                return td
            else
                intact[k,i] = false
                return 0.0
            end            
        else
            return 0.0
        end
    end

    inner_map(i, inds) = PeriDyn.norm(map((j)-> with_if_cal_td_norm(i,j), inds))
    outer_map(ARGS) = map((x)->inner_map(x[1], x[2]), ARGS)
    return outer_map(ARGS)
end

# %%
function PeriDyn.force_density_T(y::Array{Float64,2}, mat::ElastoPlasticSolidMaterial)
    types = mat.general.type
    force = zeros(size(y))
    X = Float64[1.0,0.0,0.0]
    Y = Float64[1.0,0.0,0.0]
    S = mat.general
    m = mat.general.weighted_volume
    theta = dilatation(y, S, m)
    td_norm = PeriDyn.td_norm_fn(y, theta, mat)
    δ = S.horizon
    edp = mat.specific.edp
    N = size(S.x, 2)
        
    for i in 1:N
        for k in 1:size(S.family,1)
            j = S.family[k,i]::Int64
            if !S.intact[k,i] || i==j
                # force[1,i] += 0.0
                # force[2,i] += 0.0
                # force[3,i] += 0.0
                S.intact[k,i] = false
            else
                type1 = types[i] - mat.type.start + 1
                type2 = types[j] - mat.type.start + 1
                K = mat.specific.bulk_modulus[type1, type2]
                G = mat.specific.shear_modulus[type1, type2]
                σ = mat.specific.σy[type1, type2]
                X[1],X[2],X[3] = S.x[1,j]-S.x[1,i],S.x[2,j]-S.x[2,i],S.x[3,j]-S.x[3,i]
                Y[1],Y[2],Y[3] = y[1,j]-y[1,i],y[2,j]-y[2,i],y[3,j]-y[3,i]
                _Y, _X = _magnitude(Y), _magnitude(X)
                xij = _magnitude(X)::Float64
                wij = influence_function(X)::Float64
                wji = influence_function(-X)::Float64

                e = _Y - _X
                ed = e - theta[i] * _X / 3
                ee = ed - edp[i]

                td_trial = 15*G*(ee*wij/m[i]+ee*wji/m[j])

                if td_trial > 1.0e200
                    print(td_trial, " ", ee, " ", ed, " ", edp[i], " ", e/_X)
                    error("td trial")
                end
                            
                pyf, ψ = PeriDyn.plastic_yield_function(td_trial, σ, δ)

                if pyf < 0
                    td = td_trial
                else
                    if td_norm[i]==0.0
                        td = td_trial
                    else
                        α = 15*G/m[i]
                        td = sqrt(2*ψ) * td_trial / td_norm[i]
                        Δλ = 1/α*(td_norm[i]/sqrt(2*ψ) -1)
                        if abs(Δλ*(td)) > 1.0e10
                            print(edp[i], " ", Δλ, " ", sqrt(2*ψ), " ",  
                                            td_trial, " ", td_norm[i], " ",e/_X, " ", ed)
                            error("edpi")
                        end
                        edp[i] = edp[i] + Δλ*(td)
                    end
                    if isinf(td)
                        print(ψ, " ", td_trial, " ", ed, " ", td_norm[i])
                        error("td el")
                    end                                
                end
                            
                if isnan(edp[i])
                    error("edp")
                end
                            
                            
                if (e/xij) < mat.specific.critical_stretch[type1, type2]

                    t = (3*K)*(theta[i]*xij*wij/m[i]+theta[j]*xij*wji/m[j])  
                                
                    if isinf(t)
                        error("t i")
                    end
                    if isinf(td)
                        error("td")
                    end
                                
                    t = t + td
                    t = t*S.volume[i]/_magnitude(Y)

                    if isinf(t)
                        error("t")
                    end

                    force[1,i] += t*Y[1]
                    force[2,i] += t*Y[2]
                    force[3,i] += t*Y[3]
                                                    
                                
                    if sum(isnan.(force[:, i]))!=0
                        error("f i")
                    end

                else
                    # force[1,i] += 0.0
                    # force[2,i] += 0.0
                    # force[3,i] += 0.0
                    S.intact[k,i] = false
                end
            end
        end
    end
    if sum(isnan.(force))!=0
        error("force end")
    end
    return force
end

# %%
obj = Cuboid([0 6; 0 1; 0 1])
x1, v1, y1, vol1, type1 = create(obj, resolution=0.2, type=1)
Es = 69 # GPa
nu = 0.3333    # Poisson's Ratio
K = Es/3/(1-2nu)    # Bulk Modulus
G = Es/2/(1+nu)     # Shear Modulus
den = 2440.0        # Density in Kg m ^-3
horizon = 0.6
σ = 0.002*Es
s = 0.0002
mat_gen = GeneralMaterial(y1, v1, x1, vol1, type1, 0.3; max_neigh=200)
mat_spec = ElastoPlasticSolidSpecific([K] ,[G] ,[s] , [den],[σ])
block = PeridynamicsMaterial(mat_gen, mat_spec)

# fdt=force_density_T(1.002*y1,block)
BC1 = MoveBC(y1[1, :] .< 0.5,[-0.01, 0.0, 0.0])
BC2 = MoveBC(y1[1, :] .> 5.5, [0.01, 0.0, 0.0])
k = 0.000005
exp=4.0
RM1 = NonLinearRepulsionModel(exp,k, block; distanceX=3, max_neighs=200)
dt = 0.5
env = PeriDyn.Env(1, [block], [RM1], [BC1, BC2], dt)
udf = Int(1/dt)
Steps = 100*udf


velocity_verlet!([env], Steps, filewrite_freq=udf,neigh_update_freq=udf,file_prefix="vv",start_at=0)
# Out:
# Average family members: 13.88
#
# Updating neighbors for collision..................Average repulsive neighs: 48.565333333333335
# Done
# Initial state saved.Momentum: 1[4.880000000000003; 0.0; 0.0]
#
# Writting data file................................Done
# 0.5%
#
# Writting data file................................Done
#
# Updating neighbors for collision..................Average repulsive neighs: 48.74666666666667
# 1.0%
# -1.7947877800850358e9 193622.02023510964 3.9485807317926054 2.6688422143347347e14 1.1368562763519337e10 0.0 1.7013651811515585e-18
# edpi
#
# Stacktrace:
#  [1] error(s::String)
#    @ Base ./error.jl:33
#  [2] force_density_T(y::Matrix{Float64}, mat::ElastoPlasticSolidMaterial)
#    @ Main ./In[122]:60
#  [3] update_acc!(env::PeriDyn.GeneralEnv)
#    @ PeriDyn /mnt/D/git_repos/PeriDyn/src/solvers.jl:39
#  [4] velocity_verlet_step!(env::PeriDyn.GeneralEnv)
#    @ PeriDyn /mnt/D/git_repos/PeriDyn/src/solvers.jl:74
#  [5] velocity_verlet!(envs::Vector{PeriDyn.GeneralEnv}, N::Int64; filewrite_freq::Int64, average_prop_freq::Int64, neigh_update_freq::Int64, file_prefix::String, start_at::Int64)
#    @ PeriDyn /mnt/D/git_repos/PeriDyn/src/solvers.jl:111
#  [6] top-level scope
#    @ In[123]:27
#  [7] eval
#    @ ./boot.jl:360 [inlined]
#  [8] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1116
