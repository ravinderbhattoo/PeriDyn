# %%
using Pkg

Pkg.activate("..")
using Revise

using PeriDyn
using PDMesh

using Random
using Distributed, Folds
# Out:
#   Activating environment at `/mnt/D/git_repos/PeriDyn/Project.toml`
# ┌ Info: Precompiling PeriDyn [c3db0ce0-6d7e-41b5-be11-bcb6aafada44]
# └ @ Base loading.jl:1342
# WARNING: Method definition (::Type{PeriDyn.PeridynamicsMaterial})(Any, Any, Any, Any) in module PeriDyn at /mnt/D/git_repos/PeriDyn/src/materials/material.jl:17 overwritten at /mnt/D/git_repos/PeriDyn/src/materials/pairwiseNN.jl:26.
#   ** incremental compilation may be fatally broken for this module **

# %%
PeriDyn.TIMEIT_REF[] = true
Random.seed!(42)

resolution = 1
# Out:
# 1

# %%
x1, v1, y1, vol1, type1 = create(move(Cuboid([-2 2; -2 2; 0 20]), by=[0.0, 10.0, 0]), resolution=resolution, type=1)

v1[1,:] .= 0.0

hor1 = 3.0
mat_gen1 = GeneralMaterial(y1, v1, x1, vol1, type1, hor1, max_neigh=200)

K, G = 1.0, 1.0
den1 = 10000.0
cstretch1 = 0.5
mat_spec1 = OrdinaryStateBasedSpecific([K], [G], [cstretch1], [den1])
# mat_spec1 = SkipSpecific([den1])

block1 = PeridynamicsMaterial(mat_gen1, mat_spec1; name="block 1")
# Out:
# Average family members: 47.475
# OrdinaryStateBasedMaterial("block 1", 1:1, GeneralMaterial
# type: [1]
# horizon: 3.0
# particle size: [1.0]
# , OrdinaryStateBasedSpecific
# bulk_modulus: [1.0]
# shear_modulus: [1.0]
# critical_stretch: [0.5]
# density: [10000.0]
# )

# %%
x2, v2, y2, vol2, type2 = create(move(Cuboid([-2 2; -2 2; 0 20]), by=[0.0, -10.0, 0]), resolution=resolution, type=2)

hor2 = 3.0
mat_gen2 = GeneralMaterial(y2, v2, x2, vol2, type2, hor2, max_neigh=200)

K2, G2 = 1.0, 1.0
den2 = 10000.0
cstretch2 = 0.5
mat_spec2 = OrdinaryStateBasedSpecific([K2], [G2], [cstretch2], [den2])
# mat_spec2 = SkipSpecific([den2])

block2 = PeridynamicsMaterial(mat_gen2, mat_spec2; name="block 2")
# Out:
# Average family members: 47.475
# OrdinaryStateBasedMaterial("block 2", 2:2, GeneralMaterial
# type: [2]
# horizon: 3.0
# particle size: [1.0]
# , OrdinaryStateBasedSpecific
# bulk_modulus: [1.0]
# shear_modulus: [1.0]
# critical_stretch: [0.5]
# density: [10000.0]
# )

# %%
function delete(out, mask::BitArray)
    return out[1][:, mask], out[2][:, mask], out[3][:, mask], out[4][mask], out[5][mask]
end

"""
    delete!(obj::T, f::Function) where T

Delete mesh particle for object using boolean array from function f.
"""
function delete(obj::T, f::Function) where T  
    # x, v, y, vol, type
    function func(out)
        mask = vec(f(out)) .== false
        out = delete(out, mask) 
        return out
    end
    if isa(obj, Shape)
        return PostOpObj(obj, func)
    elseif isa(obj, PostOpObj)
        push!(obj.operations, func)       
        return obj         
    else
        error("Not allowed.")
    end
end
# Out:
# delete

# %%
res = 0.5*resolution
y2, v2, x2, vol2, type2 = create(delete(move(Cylinder(9.0, 2.0, 20), by=[0.0, 0.0, 0.0]), (out)->out[1][1,:] .< 3), resolution=res, type=3)

hor2 = 3.0*res
mat_gen2 = GeneralMaterial(y2, v2, x2, vol2, type2, hor2, max_neigh=200)

K2, G2 = 1.0, 1.0
den2 = 10000.0
cstretch2 = 0.5
mat_spec2 = OrdinaryStateBasedSpecific([K2], [G2], [cstretch2], [den2])
# mat_spec2 = SkipSpecific([den2])

block3 = PeridynamicsMaterial(mat_gen2, mat_spec2; name="cylinder")
# Out:
# Average family members: 74.38217821782179
# OrdinaryStateBasedMaterial("cylinder", 3:3, GeneralMaterial
# type: [3]
# horizon: 1.5
# particle size: [0.5003430521955505]
# , OrdinaryStateBasedSpecific
# bulk_modulus: [1.0]
# shear_modulus: [1.0]
# critical_stretch: [0.5]
# density: [10000.0]
# )

# %%
x2, v2, y2, vol2, type2 = create(move(Cuboid([-2 2; -2 2; 0 20]), by=[14.0, 0.0, 0.0]), resolution=resolution, type=4)

v2[1,:] .= 0.01

hor2 = 3.0
mat_gen2 = GeneralMaterial(y2, v2, x2, vol2, type2, hor2, max_neigh=200)

K2, G2 = 1.0, 1.0
den2 = 1000.0
cstretch2 = 0.5
mat_spec2 = OrdinaryStateBasedSpecific([K2], [G2], [cstretch2], [den2])
# mat_spec2 = SkipSpecific([den2])

block4 = PeridynamicsMaterial(mat_gen2, mat_spec2; name="block 3")
# Out:
# Average family members: 47.475
# OrdinaryStateBasedMaterial("block 3", 4:4, GeneralMaterial
# type: [4]
# horizon: 3.0
# particle size: [1.0]
# , OrdinaryStateBasedSpecific
# bulk_modulus: [1.0]
# shear_modulus: [1.0]
# critical_stretch: [0.5]
# density: [1000.0]
# )

# %%
k = 1000.0
blocks = [block1, block2, block3, block4]

RM = [
        [LinearRepulsionModel(k, b1, distanceX=2, max_neighs=200) for b1 in blocks]..., 
        [LinearRepulsionModel(k, blocks[i], blocks[j], distanceX=2, max_neighs=200) for i in 2:4 for j in 1:i-1]...
    ]

env = Env(1, blocks, RM, [], 0.5)


bc = [
        MoveBC(env.type .== 4, [0.01, 0, 0]),
        FixBC(env.type .== 1),
        FixBC(env.type .== 2),
    ]

env = Env(1, blocks, RM, bc, 0.5)


nothing
#

# %%
velocity_verlet!([env], 5000, filewrite_freq=10, neigh_update_freq=10, file_prefix="half-cylinder", start_at=0)
# Out:
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 23.331930693069307
# Average repulsive neighs: 0.0
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Done
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Momentum: 1[3200.0; 6.049333126437184e-15; -3.552713678800501e-15]
#
# Writting data file................................
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Done
# 0.02%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.04%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.06%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.08%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.1%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.12%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.14%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.16%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.18%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Momentum: 10[3200.0; 4.1761732960665654e-14; -3.088307387599798e-12]
#
# Writting data file................................
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 22.645544554455444
# Average repulsive neighs: 0.0
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# 0.2%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.22%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.24%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.26%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.28%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.3%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.32%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.34%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.36%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.38%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Momentum: 20[3200.0; -2.786659791809143e-14; -1.0322853682964706e-12]
#
# Writting data file................................
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 21.871534653465346
# Average repulsive neighs: 0.0
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# 0.4%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.42%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.44%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.46%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.48%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.5%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.52%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.54%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.56%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.58%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Momentum: 30[3200.0; 1.51684220739412e-14; 2.449040970020633e-12]
#
# Writting data file................................
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 21.13589108910891
# Average repulsive neighs: 0.0
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# 0.6%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.62%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.64%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.66%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.68%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.7%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.72%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.74%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.76%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.78%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Momentum: 40[3200.0; -1.4616823376667476e-13; -2.102429341732659e-12]
#
# Writting data file................................
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 20.595049504950495
# Average repulsive neighs: 0.0
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# 0.8%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.82%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.84%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.86%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.88%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.9%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.92%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.94%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.96%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 0.98%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Momentum: 50[3200.0; -4.2754862150662376e-14; -1.73749903353837e-13]
#
# Writting data file................................
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 20.502722772277227
# Average repulsive neighs: 0.0
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# 1.0%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.02%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.04%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.06%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.08%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.1%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.12%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.14%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.16%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.18%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Momentum: 60[3200.0; 1.3665587758615594e-13; 3.0336844147882402e-12]
#
# Writting data file................................
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 20.552227722772276
# Average repulsive neighs: 0.0
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# 1.2%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.22%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.24%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.26%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.28%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.3%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.32%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.34%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.36%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.38%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Momentum: 70[3200.0; -8.47729005049036e-14; 4.604872039237762e-12]
#
# Writting data file................................
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 20.55668316831683
# Average repulsive neighs: 0.0
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# 1.4%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.42%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.44%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.46%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.48%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.5%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.52%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.54%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.56%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.58%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Momentum: 80[3200.0; -8.16451398676088e-14; 3.3650859876388495e-13]
#
# Writting data file................................
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 20.598019801980197
# Average repulsive neighs: 0.0
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# 1.6%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.62%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.64%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.66%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.68%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.7%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.72%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.74%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.76%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.78%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Momentum: 90[3200.0; -1.0603464720843059e-13; -1.7497114868092467e-13]
#
# Writting data file................................
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 20.645049504950496
# Average repulsive neighs: 0.0
# No repulsive neighs.
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# 1.8%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.82%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.84%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.86%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.88%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.9%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.92%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.94%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.96%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 1.98%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Momentum: 100[3200.0; -1.8580189470318587e-14; -1.0417222640057844e-12]
#
# Writting data file................................
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 20.650742574257425
# Average repulsive neighs: 0.0
# No repulsive neighs.
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# 2.0%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.02%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.04%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.06%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.08%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.1%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.12%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.14%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.16%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.18%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Momentum: 110[3200.0; 8.125444761475364e-14; 1.4206413823103503e-12]
#
# Writting data file................................
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 20.68168316831683
# Average repulsive neighs: 0.0
# No repulsive neighs.
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# 2.2%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.22%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.24%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.26%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.28%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.3%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.32%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.34%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.36%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.38%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Momentum: 120[3200.0; 1.5976022588182204e-13; -1.1942669075892809e-12]
#
# Writting data file................................
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 20.677475247524754
# Average repulsive neighs: 0.0
# No repulsive neighs.
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# 2.4%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.42%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.44%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.46%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.48%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.5%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.52%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.54%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.56%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.58%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Momentum: 130[3200.0; 9.828249325494198e-14; 2.355893258254582e-13]
#
# Writting data file................................
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 20.66559405940594
# Average repulsive neighs: 0.0
# No repulsive neighs.
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# 2.6%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.62%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.64%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.66%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.68%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.7%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.72%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.74%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.76%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.78%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Momentum: 140[3200.0; 5.055331153691611e-14; 3.914646384828302e-13]
#
# Writting data file................................
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 20.65
# Average repulsive neighs: 0.0
# No repulsive neighs.
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# 2.8%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.82%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.84%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.86%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.88%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.9%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.92%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.94%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.96%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 2.98%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Momentum: 150[3200.0; -2.362866846628009e-14; -1.4266365866433262e-13]
#
# Writting data file................................
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 20.592574257425742
# Average repulsive neighs: 0.0
# No repulsive neighs.
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# 3.0%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.02%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.04%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.06%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.08%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.1%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.12%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.14%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.16%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.18%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Momentum: 160[3200.0; 6.494804694057166e-15; -1.9835244557953047e-12]
#
# Writting data file................................
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 20.54529702970297
# Average repulsive neighs: 0.0
# No repulsive neighs.
# Average repulsive neighs: 0.17647058823529413
# Average repulsive neighs: 0.32142857142857145
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# 3.2%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.22%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.24%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.26%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.28%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.3%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.32%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.34%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.36%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.38%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Momentum: 170[3200.0; 3.839463469379467e-14; 1.7834622667578515e-12]
#
# Writting data file................................
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 20.503465346534654
# Average repulsive neighs: 0.0
# No repulsive neighs.
# Average repulsive neighs: 0.3235294117647059
# Average repulsive neighs: 0.5
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# 3.4%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.42%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.44%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.46%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.48%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.5%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.52%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.54%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.56%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.58%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Momentum: 180[3200.0; -1.3654008479413449e-13; 2.138844656940364e-12]
#
# Writting data file................................
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 20.465346534653467
# Average repulsive neighs: 0.0
# No repulsive neighs.
# Average repulsive neighs: 0.5588235294117647
# Average repulsive neighs: 0.75
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# 3.6%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.62%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.64%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.66%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.68%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.7%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.72%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.74%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.76%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.78%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Momentum: 190[3200.0; -1.2865750131929587e-13; 1.5611956172278951e-12]
#
# Writting data file................................
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 20.421534653465347
# Average repulsive neighs: 0.0
# No repulsive neighs.
# Average repulsive neighs: 0.6176470588235294
# Average repulsive neighs: 0.75
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# 3.8%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.82%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.84%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.86%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.88%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.9%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.92%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.94%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.96%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 3.98%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Momentum: 200[3200.0; -1.7888468484272835e-14; -8.363310044501304e-13]
#
# Writting data file................................
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 20.379950495049506
# Average repulsive neighs: 0.0
# No repulsive neighs.
# Average repulsive neighs: 0.4
# Average repulsive neighs: 0.4489795918367347
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# 4.0%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 4.02%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 4.04%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 4.06%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 4.08%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 4.1%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 4.12%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 4.14%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 4.16%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 4.18%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Momentum: 210[3200.0; -2.7700064464397656e-14; 4.360511951517765e-12]
#
# Writting data file................................
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 20.324257425742573
# Average repulsive neighs: 0.0
# No repulsive neighs.
# Average repulsive neighs: 0.40350877192982454
# Average repulsive neighs: 0.42592592592592593
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# 4.2%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 4.22%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 4.24%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 4.26%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 4.28%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 4.3%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 4.32%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 4.34%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 4.36%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 4.38%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Momentum: 220[3200.0; 1.0566200692174732e-13; -1.0126344207606053e-12]
#
# Writting data file................................
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 20.29158415841584
# Average repulsive neighs: 0.0
# No repulsive neighs.
# Average repulsive neighs: 0.6440677966101694
# Average repulsive neighs: 0.6071428571428571
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# 4.4%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 4.42%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 4.44%
# ...
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Momentum: 530[3200.0; 7.398942569736278e-14; 7.821521208484228e-12]
#
# Writting data file................................
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 18.580940594059406
# Average repulsive neighs: 0.0
# No repulsive neighs.
# Average repulsive neighs: 2.3292682926829267
# Average repulsive neighs: 2.525
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# 10.6%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 10.62%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 10.64%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 10.66%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 10.68%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 10.7%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 10.72%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 10.74%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 10.76%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 10.78%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Momentum: 540[3200.0; 1.662558979376172e-14; 1.923128323255696e-12]
#
# Writting data file................................
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 18.514851485148515
# Average repulsive neighs: 0.0
# No repulsive neighs.
# Average repulsive neighs: 2.426829268292683
# Average repulsive neighs: 2.6375
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# 10.8%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 10.82%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 10.84%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 10.86%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 10.88%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 10.9%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 10.92%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 10.94%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 10.96%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 10.98%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Momentum: 550[3200.0; 9.191258865115515e-14; 1.1029510638138618e-11]
#
# Writting data file................................
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 18.446534653465346
# Average repulsive neighs: 0.0
# No repulsive neighs.
# Average repulsive neighs: 2.5301204819277108
# Average repulsive neighs: 2.6463414634146343
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# 11.0%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 11.02%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 11.04%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 11.06%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 11.08%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 11.1%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 11.12%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 11.14%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 11.16%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 11.18%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Momentum: 560[3200.0; 1.4085260735541283e-13; 6.792788553866558e-12]
#
# Writting data file................................
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 18.375495049504952
# Average repulsive neighs: 0.0
# No repulsive neighs.
# Average repulsive neighs: 2.528735632183908
# Average repulsive neighs: 2.710843373493976
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# 11.2%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 11.22%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 11.24%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 11.26%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 11.28%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 11.3%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 11.32%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 11.34%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 11.36%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 11.38%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Momentum: 570[3200.0; 8.1601392309949e-14; 1.25910393222739e-12]
#
# Writting data file................................
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 18.308415841584157
# Average repulsive neighs: 0.0
# No repulsive neighs.
# Average repulsive neighs: 2.6091954022988504
# Average repulsive neighs: 2.8072289156626504
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# 11.4%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 11.42%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 11.44%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 11.46%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 11.48%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 11.5%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 11.52%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 11.54%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 11.56%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 11.58%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Momentum: 580[3200.0; 1.4301060335952798e-14; 5.009659354016094e-12]
#
# Writting data file................................
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Done
#
# Updating neighbors for collision..................
# Average repulsive neighs: 0.0
# Average repulsive neighs: 0.0
# Average repulsive neighs: 18.23292079207921
# Average repulsive neighs: 0.0
# No repulsive neighs.
# Average repulsive neighs: 2.647727272727273
# Average repulsive neighs: 2.8095238095238093
# Average repulsive neighs: NaN
# Average repulsive neighs: NaN
# No repulsive neighs.
# 11.6%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 11.62%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 11.64%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 11.66%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 11.68%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 11.7%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 11.72%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 11.74%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 11.76%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# 11.78%
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Momentum: 590[3200.0; -1.459943277382081e-14; 6.7981176243847585e-12]
#
# Writting data file................................
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# Material force calculation passed. [Undeformed]
# InterruptException:
#
# Stacktrace:
#   [1] _growend!
#     @ ./array.jl:888 [inlined]
#   [2] ensureroom
#     @ ./iobuffer.jl:330 [inlined]
#   [3] unsafe_write(to::IOBuffer, p::Ptr{UInt8}, nb::UInt64)
#     @ Base ./iobuffer.jl:419
#   [4] write
#     @ ./strings/io.jl:185 [inlined]
#   [5] print(io::IOBuffer, s::String)
#     @ Base ./strings/io.jl:187
#   [6] print_to_string(::Float64, ::Vararg{Any, N} where N)
#     @ Base ./strings/io.jl:135
#   [7] string
#     @ ./strings/io.jl:174 [inlined]
#   [8] #17
#     @ /mnt/D/git_repos/PeriDyn/src/util.jl:281 [inlined]
#   [9] FlipArgs
#     @ ./reduce.jl:194 [inlined]
#  [10] BottomRF
#     @ ./reduce.jl:81 [inlined]
#  [11] afoldl(::Base.BottomRF{Base.FlipArgs{PeriDyn.var"#17#21"}}, ::Base._InitialValue, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Int64, ::Int64)
#     @ Base ./operators.jl:540
#  [12] _foldl_impl
#     @ ./tuple.jl:263 [inlined]
#  [13] foldl_impl(op::Base.BottomRF{Base.FlipArgs{PeriDyn.var"#17#21"}}, nt::Base._InitialValue, itr::Tuple{Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Int64, Int64})
#     @ Base ./reduce.jl:48
#  [14] mapfoldr_impl(f::Function, op::Function, nt::Base._InitialValue, itr::Tuple{Int64, Int64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64})
#     @ Base ./reduce.jl:184
#  [15] #mapfoldr#216
#     @ ./reduce.jl:203 [inlined]
#  [16] mapfoldr
#     @ ./reduce.jl:203 [inlined]
#  [17] #foldr#217
#     @ ./reduce.jl:222 [inlined]
#  [18] foldr(op::Function, itr::Tuple{Int64, Int64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64})
#     @ Base ./reduce.jl:222
#  [19] write_data(::String, ::UnitRange{Int64}, ::Vector{Int64}, ::Matrix{Float64}, ::Matrix{Float64}, ::Matrix{Float64}, ::Vararg{Any, N} where N)
#     @ PeriDyn /mnt/D/git_repos/PeriDyn/src/util.jl:281
#  [20] save_state!(filename::String, env::PeriDyn.GeneralEnv)
#     @ PeriDyn /mnt/D/git_repos/PeriDyn/src/solvers.jl:14
#  [21] macro expansion
#     @ /mnt/D/git_repos/PeriDyn/src/macros.jl:39 [inlined]
#  [22] print_data_file!(envs::Vector{PeriDyn.GeneralEnv}, file_prefix::String, i::Int64)
#     @ PeriDyn /mnt/D/git_repos/PeriDyn/src/solvers.jl:290
#  [23] velocity_verlet!(envs::Vector{PeriDyn.GeneralEnv}, N::Int64; filewrite_freq::Int64, average_prop_freq::Int64, neigh_update_freq::Int64, file_prefix::String, start_at::Int64)
#     @ PeriDyn /mnt/D/git_repos/PeriDyn/src/solvers.jl:169
#  [24] top-level scope
#     @ In[58]:2
#  [25] eval
#     @ ./boot.jl:360 [inlined]
#  [26] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1116

# %%
using StaticArrays, Folds

function PeriDyn.force_density_T(y::Array{Float64,2}, mat::OrdinaryStateBasedMaterial)
    force = zeros(size(y))
    types = mat.general.type
    S = mat.general
    m = mat.general.weighted_volume
    intact = S.intact
    family = S.family
    PeriDyn.@timeit theta = dilatation(y, S, m) "dilation"
    N = size(S.x, 2)

    Threads.@threads for i in 1:N
        for k in 1:size(S.family,1)
            j = S.family[k,i]
            if !S.intact[k,i]
                S.intact[k,i] = false
            else
                X = PeriDyn.@_ij(j,i,S.x)
                Y = PeriDyn.@_ij(j,i,y)
                yij = PeriDyn.@_magnitude(Y)
                xij = PeriDyn.@_magnitude(X)
                
                extention = yij - xij
                wij = influence_function(X)
                wji = influence_function(-X)
                type1 = types[i] - mat.type.start + 1
                type2 = types[j] - mat.type.start + 1
                if (extention/xij) < mat.specific.critical_stretch[type1, type2]
                    K = mat.specific.bulk_modulus[type1, type2]
                    G = mat.specific.shear_modulus[type1, type2]
                    a_, b_ = wij/m[i], wji/m[j]
                    t =  (3*K-5*G) * (theta[i]*xij*a_ + theta[j]*xij*b_)  + 15*G*extention*(a_ + b_) 
                    t = t*S.volume[j] / yij
                    force[1,i] += t*Y[1]
                    force[2,i] += t*Y[2]
                    force[3,i] += t*Y[3]
                else
                    S.intact[k,i] = false
                end
            end
        end
    end

    return force
end

PeriDyn.@timeit force_density_T(1.1*block1.general.x, block1) ""
# Out:
#   0.000197 seconds (1.02 k allocations: 213.516 KiB)
# Time taken for dilation:
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
#   0.257275 seconds (321.26 k allocations: 18.100 MiB, 41.51% compilation time)
# Time taken for :
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
# 3×320 Matrix{Float64}:
#  0.305816  0.134867  -0.134867  -0.305816  …   0.134867  -0.134867  -0.305816
#  0.305816  0.341934   0.341934   0.305816     -0.341934  -0.341934  -0.305816
#  0.29763   0.330642   0.330642   0.29763      -0.330642  -0.330642  -0.29763

# %%
function PeriDyn.dilatation_theta(y::Array{Float64,2},S::GeneralMaterial)
    intact = S.intact
    family = S.family
    N = size(family, 2)

    function with_if_cal_theta_ij(i, j)
        X = PeriDyn.@_ij(j, i, S.x)
        Y = PeriDyn.@_ij(j, i, y)
        _X = PeriDyn.@_magnitude(X)
        _Y = PeriDyn.@_magnitude(Y)
        extention = _Y - _X
        return influence_function(X) * _X * extention * S.volume[j] * horizon_correction(X, S.particle_size, S.horizon)
    end

    inner_map(i, js) = mapreduce((j)-> with_if_cal_theta_ij(i,j), +, js)
    return Folds.map((i)->inner_map(i, family[intact[:, i], i]), 1:N)
    
end


S = block1.general
PeriDyn.@timeit dilatation(S.x*1.1, S, S.weighted_volume) ""
nothing
# Out:
#   0.091817 seconds (184.72 k allocations: 10.831 MiB, 88.24% compilation time)
# Time taken for :
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################

# %%
function PeriDyn.dilatation_theta(y::Array{Float64,2},S::GeneralMaterial)
    intact = S.intact
    family = S.family
    N = size(family, 2)
    M = size(family, 1)
    theta = 0*S.volume
    Threads.@threads for i in 1:N
        for k in 1:M
            j = S.family[k,i]
            if (j>0) & (intact[k, i])
                X = PeriDyn.@_ij(j, i, S.x)
                Y = PeriDyn.@_ij(j, i, y)
                _X = PeriDyn.@_magnitude(X)
                _Y = PeriDyn.@_magnitude(Y)
                extention = _Y - _X
                theta[i] += influence_function(X)*_X*extention*S.volume[j] * horizon_correction(X, S.particle_size, S.horizon)
            end
        end
    end
    return theta
end


S = block1.general
PeriDyn.@timeit dilatation(S.x*1.1, S, S.weighted_volume) ""
nothing
# Out:
#   0.103823 seconds (60.03 k allocations: 7.990 MiB, 66.31% compilation time)
# Time taken for :
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################

# %%
function PeriDyn.weighted_volume(x, volume, particle_size, family, horizon)
    N = size(family, 2)
    mask = family .> 0

    function cal_m_ij(i, j)
        X = [x[1,j]-x[1,i], x[2,j]-x[2,i], x[3,j]-x[3,i]]
        return influence_function(X)*_magnitude(X)^2*horizon_correction(X, particle_size, horizon)*volume[j]
    end
        
    inner_map(i, js) = mapreduce((j)-> cal_m_ij(i,j), +, js)
    return Folds.map((i)->inner_map(i, family[mask[:, i], i]), 1:N)
end


S = block1.general
PeriDyn.@timeit weighted_volume(S.x, S.volume, S.particle_size, S.family, S.horizon) ""
nothing
# Out:
#   4.320906 seconds (93.34 M allocations: 10.244 GiB, 40.22% gc time, 10.20% compilation time)
# Time taken for :
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################

# %%
function PeriDyn.weighted_volume(x, volume, particle_size, family, horizon)
    m = 0*volume
    dr = zeros(3)
    for i in 1:size(x,2)
        for k in 1:size(family,1)
            j = family[k,i]
            if (j>0)
                dr[1] = x[1,j]-x[1,i]
                dr[2] = x[2,j]-x[2,i]
                dr[3] = x[3,j]-x[3,i]
                m[i] += influence_function(dr)*_magnitude(dr)^2*horizon_correction(dr, particle_size,horizon)*volume[j]
            end
        end
    end
    return m
end

S = block1.general
PeriDyn.@timeit weighted_volume(S.x, S.volume, S.particle_size, S.family, S.horizon) ""
nothing
# Out:
#   0.684199 seconds (41.46 k allocations: 10.047 MiB, 6.13% compilation time)
# Time taken for :
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################

# %%
# @code_typed weighted_volume(S.x, S.volume, S.particle_size, S.family, S.horizon)

# %%
velocity_verlet!([env], 5000, filewrite_freq=10, neigh_update_freq=10, file_prefix="2blocks", start_at=0)
# Out:
# Updating neighbors for collision..................
# Average repulsive neighs: 15.625
# Done
# Material force calculation passed. [Undeformed]
#   0.752817 seconds (975.06 k allocations: 175.212 MiB, 4.31% gc time, 86.93% compilation time)
# Time taken for Material force calculations (block 1):
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
# Material force calculation passed. [Undeformed]
#   0.000137 seconds (70 allocations: 127.156 KiB)
# Time taken for Material force calculations (block 2):
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
#   1.223970 seconds (1.80 M allocations: 167.084 MiB, 3.79% gc time, 92.36% compilation time)
# Time taken for Short range repulsion calculations:
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
# Material force calculation passed. [Undeformed]
#   0.080547 seconds (187 allocations: 122.083 MiB, 7.18% gc time)
# Time taken for Material force calculations (block 1):
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
# Material force calculation passed. [Undeformed]
#   0.000138 seconds (70 allocations: 127.156 KiB)
# Time taken for Material force calculations (block 2):
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
#   0.069427 seconds (245.02 k allocations: 87.513 MiB, 8.24% gc time)
# Time taken for Short range repulsion calculations:
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
#   0.208920 seconds (245.93 k allocations: 317.396 MiB, 8.14% gc time)
# Time taken for update acceleration step:
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
#   0.231917 seconds (246.20 k allocations: 317.414 MiB, 7.34% gc time)
# Time taken for velocity verlet step:
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
# Momentum: 1[0.0; 0.0; -10000.0]
#
# Writting data file................................
# Material force calculation passed. [Undeformed]
#   0.094176 seconds (72 allocations: 122.073 MiB, 19.76% gc time)
# Time taken for Material force calculations (block 1):
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
# Material force calculation passed. [Undeformed]
#   0.000137 seconds (71 allocations: 127.688 KiB)
# Time taken for Material force calculations (block 2):
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
#   0.079262 seconds (245.02 k allocations: 87.513 MiB, 3.26% gc time)
# Time taken for Short range repulsion calculations:
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
#  12.843147 seconds (140.39 M allocations: 10.386 GiB, 10.44% gc time)
# Time taken for saving file to disk:
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
# Done
# 0.02%
#   1.867257 seconds (3.00 M allocations: 903.163 MiB, 13.97% gc time)
# Time taken for dilation:
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
#  14.513936 seconds (92.21 M allocations: 10.306 GiB, 12.66% gc time)
# Time taken for Material force calculations (block 1):
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
# Material force calculation passed. [Undeformed]
#   0.000136 seconds (70 allocations: 127.156 KiB)
# Time taken for Material force calculations (block 2):
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
#   0.070320 seconds (245.02 k allocations: 87.513 MiB, 14.54% gc time)
# Time taken for Short range repulsion calculations:
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
#  14.643912 seconds (92.45 M allocations: 10.497 GiB, 12.66% gc time)
# Time taken for update acceleration step:
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
#  14.666341 seconds (92.45 M allocations: 10.497 GiB, 12.64% gc time)
# Time taken for velocity verlet step:
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
# 0.04%
#   1.875054 seconds (3.00 M allocations: 903.163 MiB, 13.82% gc time)
# Time taken for dilation:
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# #############################################################
# InterruptException:
#
# Stacktrace:
#   [1] Array
#     @ ./boot.jl:448 [inlined]
#   [2] Array
#     @ ./boot.jl:457 [inlined]
#   [3] Array
#     @ ./boot.jl:465 [inlined]
#   [4] similar
#     @ ./abstractarray.jl:785 [inlined]
#   [5] similar
#     @ ./abstractarray.jl:784 [inlined]
#   [6] similar
#     @ ./broadcast.jl:197 [inlined]
#   [7] similar
#     @ ./broadcast.jl:196 [inlined]
#   [8] copy
#     @ ./broadcast.jl:908 [inlined]
#   [9] materialize
#     @ ./broadcast.jl:883 [inlined]
#  [10] broadcast_preserving_zero_d
#     @ ./broadcast.jl:872 [inlined]
#  [11] -(A::Vector{Float64})
#     @ Base ./arraymath.jl:30
#  [12] force_density_T(y::Matrix{Float64}, mat::OrdinaryStateBasedMaterial)
#     @ PeriDyn /mnt/D/git_repos/PeriDyn/src/materials/ordinary_state_based.jl:64
#  [13] force_density(y::Matrix{Float64}, mat::OrdinaryStateBasedMaterial)
#     @ PeriDyn /mnt/D/git_repos/PeriDyn/src/materials/material.jl:89
#  [14] macro expansion
#     @ ./timing.jl:210 [inlined]
#  [15] macro expansion
#     @ /mnt/D/git_repos/PeriDyn/src/PeriDyn.jl:30 [inlined]
#  [16] update_acc!(env::PeriDyn.GeneralEnv)
#     @ PeriDyn /mnt/D/git_repos/PeriDyn/src/solvers.jl:51
#  [17] macro expansion
#     @ ./timing.jl:210 [inlined]
#  [18] macro expansion
#     @ /mnt/D/git_repos/PeriDyn/src/PeriDyn.jl:30 [inlined]
#  [19] velocity_verlet_step!(env::PeriDyn.GeneralEnv)
#     @ PeriDyn /mnt/D/git_repos/PeriDyn/src/solvers.jl:95
#  [20] macro expansion
#     @ ./timing.jl:210 [inlined]
#  [21] macro expansion
#     @ /mnt/D/git_repos/PeriDyn/src/PeriDyn.jl:30 [inlined]
#  [22] velocity_verlet!(envs::Vector{PeriDyn.GeneralEnv}, N::Int64; filewrite_freq::Int64, average_prop_freq::Int64, neigh_update_freq::Int64, file_prefix::String, start_at::Int64)
#     @ PeriDyn /mnt/D/git_repos/PeriDyn/src/solvers.jl:144
#  [23] top-level scope
#     @ In[164]:1
#  [24] eval
#     @ ./boot.jl:360 [inlined]
#  [25] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1116

# %% [markdown]
# ## END

# %%
function PeriDyn.td_norm_fn(y, theta, mat)
    S = mat.general
    types = mat.general.type
    intact = S.intact
    family = S.family
    x = S.x
    N = size(family, 2)
    M = size(family, 1)
    ARGS = map((i) -> (i, 1:M), 1:N)    
    m = mat.general.weighted_volume
    function with_if_cal_td_norm(i, k)
        if intact[k,i]
            j = family[k, i]
            type1 = types[i] - mat.type.start + 1
            type2 = types[j] - mat.type.start + 1
            G = mat.specific.shear_modulus[type1, type2]
            edp = mat.specific.edp[k, i]

            X = [x[1,j]-x[1,i],x[2,j]-x[2,i],x[3,j]-x[3,i]]
            Y = [y[1,j]-y[1,i],y[2,j]-y[2,i],y[3,j]-y[3,i]]

            _X = _magnitude(X)
            _Y = _magnitude(Y)

            e = _Y - _X

            ed = e - theta[i] * _X / 3
                        
            ee = ed - edp

            s = e/_X

            wij = influence_function(X)::Float64
            wji = influence_function(-X)::Float64
            type1 = types[i] - mat.type.start + 1
            type2 = types[j] - mat.type.start + 1
            if s < mat.specific.critical_stretch[type1, type2]
                K = mat.specific.bulk_modulus[type1, type2]
                G = mat.specific.shear_modulus[type1, type2]
                td = 15*G*(ee*wij/m[i]+ee*wji/m[j])
                return td
            else
                intact[k,i] = false
                return 0.0
            end            
        else
            return 0.0
        end
    end

    inner_map(i, inds) = PeriDyn.norm(map((j)-> with_if_cal_td_norm(i,j), inds))
    outer_map(ARGS) = map((x)->inner_map(x[1], x[2]), ARGS)
    return outer_map(ARGS)
end

# %%
function PeriDyn.force_density_T(y::Array{Float64,2}, mat::ElastoPlasticSolidMaterial)
    types = mat.general.type
    force = zeros(size(y))
    X = Float64[1.0,0.0,0.0]
    Y = Float64[1.0,0.0,0.0]
    S = mat.general
    m = mat.general.weighted_volume
    theta = dilatation(y, S, m)
    td_norm = PeriDyn.td_norm_fn(y, theta, mat)
    δ = S.horizon
    edp = mat.specific.edp
    N = size(S.x, 2)
        
    for i in 1:N
        for k in 1:size(S.family,1)
            j = S.family[k,i]::Int64
            if !S.intact[k,i] || i==j
                # force[1,i] += 0.0
                # force[2,i] += 0.0
                # force[3,i] += 0.0
                S.intact[k,i] = false
            else
                type1 = types[i] - mat.type.start + 1
                type2 = types[j] - mat.type.start + 1
                K = mat.specific.bulk_modulus[type1, type2]
                G = mat.specific.shear_modulus[type1, type2]
                σ = mat.specific.σy[type1, type2]
                X[1],X[2],X[3] = S.x[1,j]-S.x[1,i],S.x[2,j]-S.x[2,i],S.x[3,j]-S.x[3,i]
                Y[1],Y[2],Y[3] = y[1,j]-y[1,i],y[2,j]-y[2,i],y[3,j]-y[3,i]
                _Y, _X = _magnitude(Y), _magnitude(X)
                xij = _magnitude(X)::Float64
                wij = influence_function(X)::Float64
                wji = influence_function(-X)::Float64

                e = _Y - _X
                ed = e - theta[i] * _X / 3
                ee = ed - edp[i]

                td_trial = 15*G*(ee*wij/m[i]+ee*wji/m[j])

                if td_trial > 1.0e200
                    print(td_trial, " ", ee, " ", ed, " ", edp[i], " ", e/_X)
                    error("td trial")
                end
                            
                pyf, ψ = PeriDyn.plastic_yield_function(td_trial, σ, δ)

                if pyf < 0
                    td = td_trial
                else
                    if td_norm[i]==0.0
                        td = td_trial
                    else
                        α = 15*G/m[i]
                        td = sqrt(2*ψ) * td_trial / td_norm[i]
                        Δλ = 1/α*(td_norm[i]/sqrt(2*ψ) -1)
                        if abs(Δλ*(td)) > 1.0e10
                            print(edp[i], " ", Δλ, " ", sqrt(2*ψ), " ",  
                                            td_trial, " ", td_norm[i], " ",e/_X, " ", ed)
                            error("edpi")
                        end
                        edp[i] = edp[i] + Δλ*(td)
                    end
                    if isinf(td)
                        print(ψ, " ", td_trial, " ", ed, " ", td_norm[i])
                        error("td el")
                    end                                
                end
                            
                if isnan(edp[i])
                    error("edp")
                end
                            
                            
                if (e/xij) < mat.specific.critical_stretch[type1, type2]

                    t = (3*K)*(theta[i]*xij*wij/m[i]+theta[j]*xij*wji/m[j])  
                                
                    if isinf(t)
                        error("t i")
                    end
                    if isinf(td)
                        error("td")
                    end
                                
                    t = t + td
                    t = t*S.volume[i]/_magnitude(Y)

                    if isinf(t)
                        error("t")
                    end

                    force[1,i] += t*Y[1]
                    force[2,i] += t*Y[2]
                    force[3,i] += t*Y[3]
                                                    
                                
                    if sum(isnan.(force[:, i]))!=0
                        error("f i")
                    end

                else
                    # force[1,i] += 0.0
                    # force[2,i] += 0.0
                    # force[3,i] += 0.0
                    S.intact[k,i] = false
                end
            end
        end
    end
    if sum(isnan.(force))!=0
        error("force end")
    end
    return force
end

# %%
obj = Cuboid([0 6; 0 1; 0 1])
x1, v1, y1, vol1, type1 = create(obj, resolution=0.2, type=1)
Es = 69 # GPa
nu = 0.3333    # Poisson's Ratio
K = Es/3/(1-2nu)    # Bulk Modulus
G = Es/2/(1+nu)     # Shear Modulus
den = 2440.0        # Density in Kg m ^-3
horizon = 0.6
σ = 0.002*Es
s = 0.0002
mat_gen = GeneralMaterial(y1, v1, x1, vol1, type1, 0.3; max_neigh=200)
mat_spec = ElastoPlasticSolidSpecific([K] ,[G] ,[s] , [den],[σ])
block = PeridynamicsMaterial(mat_gen, mat_spec)

# fdt=force_density_T(1.002*y1,block)
BC1 = MoveBC(y1[1, :] .< 0.5,[-0.01, 0.0, 0.0])
BC2 = MoveBC(y1[1, :] .> 5.5, [0.01, 0.0, 0.0])
k = 0.000005
exp=4.0
RM1 = NonLinearRepulsionModel(exp,k, block; distanceX=3, max_neighs=200)
dt = 0.5
env = PeriDyn.Env(1, [block], [RM1], [BC1, BC2], dt)
udf = Int(1/dt)
Steps = 100*udf


velocity_verlet!([env], Steps, filewrite_freq=udf,neigh_update_freq=udf,file_prefix="vv",start_at=0)
# Out:
# Average family members: 13.88
#
# Updating neighbors for collision..................Average repulsive neighs: 48.565333333333335
# Done
# Initial state saved.Momentum: 1[4.880000000000003; 0.0; 0.0]
#
# Writting data file................................Done
# 0.5%
#
# Writting data file................................Done
#
# Updating neighbors for collision..................Average repulsive neighs: 48.74666666666667
# 1.0%
# -1.7947877800850358e9 193622.02023510964 3.9485807317926054 2.6688422143347347e14 1.1368562763519337e10 0.0 1.7013651811515585e-18
# edpi
#
# Stacktrace:
#  [1] error(s::String)
#    @ Base ./error.jl:33
#  [2] force_density_T(y::Matrix{Float64}, mat::ElastoPlasticSolidMaterial)
#    @ Main ./In[122]:60
#  [3] update_acc!(env::PeriDyn.GeneralEnv)
#    @ PeriDyn /mnt/D/git_repos/PeriDyn/src/solvers.jl:39
#  [4] velocity_verlet_step!(env::PeriDyn.GeneralEnv)
#    @ PeriDyn /mnt/D/git_repos/PeriDyn/src/solvers.jl:74
#  [5] velocity_verlet!(envs::Vector{PeriDyn.GeneralEnv}, N::Int64; filewrite_freq::Int64, average_prop_freq::Int64, neigh_update_freq::Int64, file_prefix::String, start_at::Int64)
#    @ PeriDyn /mnt/D/git_repos/PeriDyn/src/solvers.jl:111
#  [6] top-level scope
#    @ In[123]:27
#  [7] eval
#    @ ./boot.jl:360 [inlined]
#  [8] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1116
